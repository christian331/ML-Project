# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# read the data
df = pd.read_csv('all_data.csv')

# shape and data types of the data
print(df.shape)
print(df.dtypes)

# select numeric columns
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)

# select non numeric columns
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# C:\Users\Raharijaona\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8,26,78,88,94,98,105,113,116,117,125,126,127,128,129,130,131,133,134,135,136,137,138,139,140,146,147,149,150,153,154,156,157,158,159,160,161,162,163,166,167,169,170,171,172,173,174,175,176,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (14929, 283)
# Listing Number          int64
# Type of Property       object
# Listing Date           object
# Erf Size               object
# Pets Allowed           object
#                         ...
# Pool 4                 object
# Family/TV Room 4       object
# Entrance Hall 4        object
# Special Features 12    object
# Lease Period           object
# Length: 283, dtype: object
# ['Listing Number' 'Reception Rooms' 'Secure Parking' 'Entrance Halls'
#  'Family/TV Rooms' 'Outside Toilets' 'Office' 'Pools' 'Age'
#  'Domestic Bathrooms' 'Braai Rooms' 'Floor Number' 'Number of floors'
#  'Common Toilets' 'Lofts']
# ['Type of Property' 'Listing Date' 'Erf Size' 'Pets Allowed' 'Bedrooms'
#  'Bathrooms' 'Kitchens' 'Dining Rooms' 'Parking' 'Bedroom 1' 'Bedroom 2'
#  'Bedroom 3' 'Bathroom 1' 'Bathroom 2' 'Kitchen' 'Lounge' 'Parking 1'
#  'Parking 2' 'Garden' 'Pool' 'Security' 'Floor Size' 'Levies'
#  'Special Levy' 'Rates and Taxes' 'Lounges' 'Rooms' 'Garage' 'Floor'
#  'Internet Access' 'Street Address' 'Description' 'Lifestyle'
#  'Price per m�' 'No Transfer Duty' 'Bathroom' 'Nearby Public Transport'
#  'Bedroom 4' 'Bathroom 3' 'Bathroom 4' 'Domestic Rooms' 'Dining Room'
#  'Family/TV Room' 'Entrance Hall' 'Outbuilding' 'Special Features'
#  'Special Feature' 'Coverage' 'Style' 'Facing' 'Roof' 'Wall' 'Window'
#  'Standalone Building' 'Wheelchair Accessible' 'Generator' 'Backup Water'
#  'Bedroom 5' 'Bedroom 6' 'Bathroom 5' 'Kitchen 1' 'Kitchen 2'
#  'Office/study' 'Lounge 1' 'Lounge 2' 'Dining Room 1' 'Dining Room 2'
#  'Parking 3' 'Parking 4' 'Garage 1' 'Garage 2' 'Outbuildings'
#  'Outbuilding 1' 'Outbuilding 2' 'Temperature Control' 'Bars' 'Other'
#  'Parking 5' 'Flatlet' 'Flat Description' 'Braai Room' 'Gardens'
#  'Size of Outbuildings' 'Outbuilding 3' 'Outbuilding 4' 'Office/studies'
#  'Bedroom' 'Other 1' 'Other 2' 'Special Featuress' 'Special Features 1'
#  'Special Features 2' 'Special Features 3' 'Special Features 4'
#  'Special Features 5' 'Special Features 6' 'Second House' 'Other 3'
#  'Furnished' 'Garage 3' 'Garden 1' 'Garden 2' 'Temperature Controls'
#  'Bedroom 7' 'Bedroom 8' 'Bedroom 9' 'Bedroom 10' 'Garage 4' 'Loft'
#  'Security 1' 'Security 2' 'Security 3' 'Security 4' 'Security 5'
#  'Security 6' 'Security 7' 'Security 8' 'Security 9' 'Lounge 3' 'Lounge 4'
#  'Lounge 5' 'Lounge 6' 'Lounge 7' 'Lounge 8' 'Lounge 9' 'Lounge 10'
#  'Lounge 11' 'Family/TV Room 1' 'Family/TV Room 2' 'Bar' 'Kitchen 3'
#  'Kitchen 4' 'Kitchen 5' 'Kitchen 6' 'Parking 6' 'Parking 7' 'Parking 8'
#  'Other 4' 'Special Features 7' 'Special Features 8' 'Special Features 9'
#  'Bathroom 6' 'Other 5' 'Other 6' 'Other 7' 'Other 8' 'Other 9' 'Other 10'
#  'Braai Room 1' 'Braai Room 2' 'Office 1' 'Office 2' 'Office 3' 'Office 4'
#  'Zoning' 'Bedroom 11' 'Entrance Hall 1' 'Entrance Hall 2' 'Parking 9'
#  'Parking 10' 'Temperature Control 1' 'Temperature Control 2'
#  'Security 10' 'Bathroom 7' 'Garage 5' 'Outbuilding 5' 'Outbuilding 6'
#  'Garage 6' 'Garage 7' 'Garage 8' 'Bathroom 8' 'Bathroom 9' 'Bathroom 10'
#  'Bathroom 11' 'Bedroom 12' 'Bedroom 13' 'Bedroom 14' 'Bedroom 15'
#  'Bedroom 16' 'Bathroom 12' 'Bathroom 13' 'Bathroom 14' 'Bathroom 15'
#  'Bathroom 16' 'Garden 3' 'Dining Room 3' 'Dining Room 4' 'Parking 11'
#  'Parking 12' 'Parking 13' 'Parking 14' 'Price Per Parking' 'Pool 1'
#  'Pool 2' 'Height Restriction' 'Deposit Requirements' 'Family/TV Room 3'
#  'Braai Room 3' 'Bar 1' 'Bar 2' 'Parking 15' 'Parking 16' 'Parking 17'
#  'Parking 18' 'Parking 19' 'Parking 20' 'Parking 21' 'Parking 22'
#  'Parking 23' 'Parking 24' 'Outbuilding 7' 'Outbuilding 8' 'Outbuilding 9'
#  'Outbuilding 10' 'Outbuilding 11' 'Outbuilding 12' 'Outbuilding 13'
#  'Other 11' 'Other 12' 'Other 13' 'Other 14' 'Special Features 10'
#  'Special Features 11' 'Braai Room 4' 'Braai Room 5' 'Braai Room 6'
#  'Braai Room 7' 'Braai Room 8' 'Pool 3' 'Bathroom 17' 'Bedroom 17'
#  'Bedroom 18' 'Bedroom 19' 'Bedroom 20' 'Bedroom 21' 'Bedroom 22'
#  'Bedroom 23' 'Bedroom 24' 'Bathroom 18' 'Garage 9' 'Garage 10' 'Garden 4'
#  'Garden 5' 'Bathroom 20' 'Bathroom 21' 'Office 5' 'Office 6' 'Office 7'
#  'Office 8' 'Office 9' 'Office 10' 'Office 11' 'Office 12' 'Office 13'
#  'Office 14' 'Office 15' 'Kitchen 7' 'Kitchen 8' 'Kitchen 9' 'Loft 1'
#  'Loft 2' 'Loft 3' 'Entrance Hall 3' 'Pool 4' 'Family/TV Room 4'
#  'Entrance Hall 4' 'Special Features 12' 'Lease Period']

# %%
df
# Out:
#        Listing Number  Type of Property    Listing Date Erf Size Pets Allowed  \
# 0           110274587             House  05 August 2021   220 m�          Yes
# 1           110274508  Apartment / Flat  05 August 2021      NaN           No
# 2           110274181             House  05 August 2021   319 m�          Yes
# 3           110274123             House  05 August 2021   150 m�          Yes
# 4           110274104  Apartment / Flat  05 August 2021      NaN          NaN
# ...               ...               ...             ...      ...          ...
# 14924       110270466             House  05 August 2021  59.9 ha          Yes
# 14925       110270461  Apartment / Flat  05 August 2021      NaN          NaN
# 14926       110270333  Apartment / Flat  05 August 2021      NaN          NaN
# 14927       110270263             House  05 August 2021   632 m�          Yes
# 14928       110272183             House  05 August 2021   270 m�          Yes
#
#       Bedrooms Bathrooms Kitchens Dining Rooms          Parking  ...  \
# 0            3         2        1            1                2  ...
# 1            3         2      NaN          NaN                2  ...
# 2            3         2        1            1              NaN  ...
# 3            2         1        1          NaN              NaN  ...
# 4            2       NaN      NaN          NaN  Carport, Single  ...
# ...        ...       ...      ...          ...              ...  ...
# 14924        3         5        1          NaN                2  ...
# 14925      NaN       NaN      NaN          NaN              NaN  ...
# 14926      NaN         1        1          NaN              NaN  ...
# 14927        3         2        1          NaN                2  ...
# 14928        4       3.5      NaN          1.0                1  ...
#
#       Kitchen 9 Loft 1 Loft 2 Loft 3 Entrance Hall 3 Pool 4 Family/TV Room 4  \
# 0           NaN    NaN    NaN    NaN             NaN    NaN              NaN
# 1           NaN    NaN    NaN    NaN             NaN    NaN              NaN
# 2           NaN    NaN    NaN    NaN             NaN    NaN              NaN
# 3           NaN    NaN    NaN    NaN             NaN    NaN              NaN
# 4           NaN    NaN    NaN    NaN             NaN    NaN              NaN
# ...         ...    ...    ...    ...             ...    ...              ...
# 14924       NaN    NaN    NaN    NaN             NaN    NaN              NaN
# 14925       NaN    NaN    NaN    NaN             NaN    NaN              NaN
# 14926       NaN    NaN    NaN    NaN             NaN    NaN              NaN
# 14927       NaN    NaN    NaN    NaN             NaN    NaN              NaN
# 14928       NaN    NaN    NaN    NaN             NaN    NaN              NaN
#
#       Entrance Hall 4 Special Features 12 Lease Period
# 0                 NaN                 NaN          NaN
# 1                 NaN                 NaN          NaN
# 2                 NaN                 NaN          NaN
# 3                 NaN                 NaN          NaN
# 4                 NaN                 NaN          NaN
# ...               ...                 ...          ...
# 14924             NaN                 NaN          NaN
# 14925             NaN                 NaN          NaN
# 14926             NaN                 NaN          NaN
# 14927             NaN                 NaN          NaN
# 14928             NaN                 NaN          NaN
#
# [14929 rows x 283 columns]

# %%
cols_to_drop = []
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    if round(pct_missing*100)>90:
        print('{} - {}%'.format(col, round(pct_missing*100)))
        cols_to_drop.append(col)
# Out:
# Parking 1 - 92%
# Parking 2 - 92%
# Special Levy - 96%
# Floor - 96%
# No Transfer Duty - 92%
# Bathroom 4 - 95%
# Secure Parking - 98%
# Wheelchair Accessible - 92%
# Generator - 95%
# Backup Water - 93%
# Bedroom 5 - 96%
# Bedroom 6 - 98%
# Bathroom 5 - 98%
# Kitchen 1 - 99%
# Kitchen 2 - 99%
# Office/study - 93%
# Lounge 1 - 97%
# Lounge 2 - 97%
# Dining Room 1 - 99%
# Dining Room 2 - 99%
# Parking 3 - 97%
# Parking 4 - 98%
# Outbuildings - 95%
# Outbuilding 1 - 97%
# Outbuilding 2 - 97%
# Temperature Control - 92%
# Bars - 99%
# Entrance Halls - 97%
# Family/TV Rooms - 95%
# Outside Toilets - 98%
# Other - 91%
# Parking 5 - 99%
# Flat Description - 98%
# Braai Room - 94%
# Office - 92%
# Pools - 94%
# Size of Outbuildings - 99%
# Age - 96%
# Outbuilding 3 - 99%
# Outbuilding 4 - 100%
# Office/studies - 95%
# Bedroom - 95%
# Other 1 - 98%
# Other 2 - 98%
# Special Featuress - 95%
# Special Features 1 - 95%
# Special Features 2 - 95%
# Special Features 3 - 96%
# Special Features 4 - 97%
# Special Features 5 - 97%
# Special Features 6 - 99%
# Second House - 100%
# Other 3 - 99%
# Domestic Bathrooms - 98%
# Furnished - 98%
# Garage 3 - 98%
# Garden 1 - 100%
# Garden 2 - 100%
# Braai Rooms - 99%
# Temperature Controls - 99%
# Bedroom 7 - 99%
# Bedroom 8 - 99%
# Bedroom 9 - 100%
# Bedroom 10 - 100%
# Garage 4 - 99%
# Loft - 100%
# Floor Number - 98%
# Number of floors - 99%
# Common Toilets - 100%
# Security 1 - 100%
# Security 2 - 100%
# Security 3 - 100%
# Security 4 - 100%
# Security 5 - 100%
# Security 6 - 100%
# Security 7 - 100%
# Security 8 - 100%
# Security 9 - 100%
# Lounge 3 - 100%
# Lounge 4 - 100%
# Lounge 5 - 100%
# Lounge 6 - 100%
# Lounge 7 - 100%
# Lounge 8 - 100%
# Lounge 9 - 100%
# Lounge 10 - 100%
# Lounge 11 - 100%
# Family/TV Room 1 - 100%
# Family/TV Room 2 - 100%
# Bar - 99%
# Kitchen 3 - 100%
# Kitchen 4 - 100%
# Kitchen 5 - 100%
# Kitchen 6 - 100%
# Parking 6 - 99%
# Parking 7 - 100%
# Parking 8 - 100%
# Other 4 - 100%
# Special Features 7 - 100%
# Special Features 8 - 100%
# Special Features 9 - 100%
# Bathroom 6 - 99%
# Other 5 - 100%
# Other 6 - 100%
# Other 7 - 100%
# Other 8 - 100%
# Other 9 - 100%
# Other 10 - 100%
# Braai Room 1 - 100%
# Braai Room 2 - 100%
# Office 1 - 100%
# Office 2 - 100%
# Office 3 - 100%
# Office 4 - 100%
# Zoning - 99%
# Bedroom 11 - 100%
# Entrance Hall 1 - 100%
# Entrance Hall 2 - 100%
# Parking 9 - 100%
# Parking 10 - 100%
# Temperature Control 1 - 100%
# Temperature Control 2 - 100%
# Security 10 - 100%
# Bathroom 7 - 100%
# Garage 5 - 100%
# Lofts - 100%
# Outbuilding 5 - 100%
# Outbuilding 6 - 100%
# Garage 6 - 100%
# Garage 7 - 100%
# Garage 8 - 100%
# Bathroom 8 - 100%
# Bathroom 9 - 100%
# Bathroom 10 - 100%
# Bathroom 11 - 100%
# Bedroom 12 - 100%
# Bedroom 13 - 100%
# Bedroom 14 - 100%
# Bedroom 15 - 100%
# Bedroom 16 - 100%
# Bathroom 12 - 100%
# Bathroom 13 - 100%
# Bathroom 14 - 100%
# Bathroom 15 - 100%
# Bathroom 16 - 100%
# Garden 3 - 100%
# Dining Room 3 - 100%
# Dining Room 4 - 100%
# Parking 11 - 100%
# Parking 12 - 100%
# Parking 13 - 100%
# Parking 14 - 100%
# Price Per Parking - 100%
# Pool 1 - 100%
# Pool 2 - 100%
# Height Restriction - 100%
# Deposit Requirements - 100%
# Family/TV Room 3 - 100%
# Braai Room 3 - 100%
# Bar 1 - 100%
# Bar 2 - 100%
# Parking 15 - 100%
# Parking 16 - 100%
# Parking 17 - 100%
# Parking 18 - 100%
# Parking 19 - 100%
# Parking 20 - 100%
# Parking 21 - 100%
# Parking 22 - 100%
# Parking 23 - 100%
# Parking 24 - 100%
# Outbuilding 7 - 100%
# Outbuilding 8 - 100%
# Outbuilding 9 - 100%
# Outbuilding 10 - 100%
# Outbuilding 11 - 100%
# Outbuilding 12 - 100%
# Outbuilding 13 - 100%
# Other 11 - 100%
# Other 12 - 100%
# Other 13 - 100%
# Other 14 - 100%
# Special Features 10 - 100%
# Special Features 11 - 100%
# Braai Room 4 - 100%
# Braai Room 5 - 100%
# Braai Room 6 - 100%
# Braai Room 7 - 100%
# Braai Room 8 - 100%
# Pool 3 - 100%
# Bathroom 17 - 100%
# Bedroom 17 - 100%
# Bedroom 18 - 100%
# Bedroom 19 - 100%
# Bedroom 20 - 100%
# Bedroom 21 - 100%
# Bedroom 22 - 100%
# Bedroom 23 - 100%
# Bedroom 24 - 100%
# Bathroom 18 - 100%
# Garage 9 - 100%
# Garage 10 - 100%
# Garden 4 - 100%
# Garden 5 - 100%
# Bathroom 20 - 100%
# Bathroom 21 - 100%
# Office 5 - 100%
# Office 6 - 100%
# Office 7 - 100%
# Office 8 - 100%
# Office 9 - 100%
# Office 10 - 100%
# Office 11 - 100%
# Office 12 - 100%
# Office 13 - 100%
# Office 14 - 100%
# Office 15 - 100%
# Kitchen 7 - 100%
# Kitchen 8 - 100%
# Kitchen 9 - 100%
# Loft 1 - 100%
# Loft 2 - 100%
# Loft 3 - 100%
# Entrance Hall 3 - 100%
# Pool 4 - 100%
# Family/TV Room 4 - 100%
# Entrance Hall 4 - 100%
# Special Features 12 - 100%
# Lease Period - 100%

# %%
cols_to_drop
# Out:
# ['Parking 1',
#  'Parking 2',
#  'Special Levy',
#  'Floor',
#  'No Transfer Duty',
#  'Bathroom 4',
#  'Secure Parking',
#  'Wheelchair Accessible',
#  'Generator',
#  'Backup Water',
#  'Bedroom 5',
#  'Bedroom 6',
#  'Bathroom 5',
#  'Kitchen 1',
#  'Kitchen 2',
#  'Office/study',
#  'Lounge 1',
#  'Lounge 2',
#  'Dining Room 1',
#  'Dining Room 2',
#  'Parking 3',
#  'Parking 4',
#  'Outbuildings',
#  'Outbuilding 1',
#  'Outbuilding 2',
#  'Temperature Control',
#  'Bars',
#  'Entrance Halls',
#  'Family/TV Rooms',
#  'Outside Toilets',
#  'Other',
#  'Parking 5',
#  'Flat Description',
#  'Braai Room',
#  'Office',
#  'Pools',
#  'Size of Outbuildings',
#  'Age',
#  'Outbuilding 3',
#  'Outbuilding 4',
#  'Office/studies',
#  'Bedroom',
#  'Other 1',
#  'Other 2',
#  'Special Featuress',
#  'Special Features 1',
#  'Special Features 2',
#  'Special Features 3',
#  'Special Features 4',
#  'Special Features 5',
#  'Special Features 6',
#  'Second House',
#  'Other 3',
#  'Domestic Bathrooms',
#  'Furnished',
#  'Garage 3',
#  'Garden 1',
#  'Garden 2',
#  'Braai Rooms',
#  'Temperature Controls',
#  'Bedroom 7',
#  'Bedroom 8',
#  'Bedroom 9',
#  'Bedroom 10',
#  'Garage 4',
#  'Loft',
#  'Floor Number',
#  'Number of floors',
#  'Common Toilets',
#  'Security 1',
#  'Security 2',
#  'Security 3',
#  'Security 4',
#  'Security 5',
#  'Security 6',
#  'Security 7',
#  'Security 8',
#  'Security 9',
#  'Lounge 3',
#  'Lounge 4',
#  'Lounge 5',
#  'Lounge 6',
#  'Lounge 7',
#  'Lounge 8',
#  'Lounge 9',
#  'Lounge 10',
#  'Lounge 11',
#  'Family/TV Room 1',
#  'Family/TV Room 2',
#  'Bar',
#  'Kitchen 3',
#  'Kitchen 4',
#  'Kitchen 5',
#  'Kitchen 6',
#  'Parking 6',
#  'Parking 7',
#  'Parking 8',
#  'Other 4',
#  'Special Features 7',
#  'Special Features 8',
#  'Special Features 9',
#  'Bathroom 6',
#  'Other 5',
#  'Other 6',
#  'Other 7',
#  'Other 8',
#  'Other 9',
#  'Other 10',
#  'Braai Room 1',
#  'Braai Room 2',
#  'Office 1',
#  'Office 2',
#  'Office 3',
#  'Office 4',
#  'Zoning',
#  'Bedroom 11',
#  'Entrance Hall 1',
#  'Entrance Hall 2',
#  'Parking 9',
#  'Parking 10',
#  'Temperature Control 1',
#  'Temperature Control 2',
#  'Security 10',
#  'Bathroom 7',
#  'Garage 5',
#  'Lofts',
#  'Outbuilding 5',
#  'Outbuilding 6',
#  'Garage 6',
#  'Garage 7',
#  'Garage 8',
#  'Bathroom 8',
#  'Bathroom 9',
#  'Bathroom 10',
#  'Bathroom 11',
#  'Bedroom 12',
#  'Bedroom 13',
#  'Bedroom 14',
#  'Bedroom 15',
#  'Bedroom 16',
#  'Bathroom 12',
#  'Bathroom 13',
#  'Bathroom 14',
#  'Bathroom 15',
#  'Bathroom 16',
#  'Garden 3',
#  'Dining Room 3',
#  'Dining Room 4',
#  'Parking 11',
#  'Parking 12',
#  'Parking 13',
#  'Parking 14',
#  'Price Per Parking',
#  'Pool 1',
#  'Pool 2',
#  'Height Restriction',
#  'Deposit Requirements',
#  'Family/TV Room 3',
#  'Braai Room 3',
#  'Bar 1',
#  'Bar 2',
#  'Parking 15',
#  'Parking 16',
#  'Parking 17',
#  'Parking 18',
#  'Parking 19',
#  'Parking 20',
#  'Parking 21',
#  'Parking 22',
#  'Parking 23',
#  'Parking 24',
#  'Outbuilding 7',
#  'Outbuilding 8',
#  'Outbuilding 9',
#  'Outbuilding 10',
#  'Outbuilding 11',
#  'Outbuilding 12',
#  'Outbuilding 13',
#  'Other 11',
#  'Other 12',
#  'Other 13',
#  'Other 14',
#  'Special Features 10',
#  'Special Features 11',
#  'Braai Room 4',
#  'Braai Room 5',
#  'Braai Room 6',
#  'Braai Room 7',
#  'Braai Room 8',
#  'Pool 3',
#  'Bathroom 17',
#  'Bedroom 17',
#  'Bedroom 18',
#  'Bedroom 19',
#  'Bedroom 20',
#  'Bedroom 21',
#  'Bedroom 22',
#  'Bedroom 23',
#  'Bedroom 24',
#  'Bathroom 18',
#  'Garage 9',
#  'Garage 10',
#  'Garden 4',
#  'Garden 5',
#  'Bathroom 20',
#  'Bathroom 21',
#  'Office 5',
#  'Office 6',
#  'Office 7',
#  'Office 8',
#  'Office 9',
#  'Office 10',
#  'Office 11',
#  'Office 12',
#  'Office 13',
#  'Office 14',
#  'Office 15',
#  'Kitchen 7',
#  'Kitchen 8',
#  'Kitchen 9',
#  'Loft 1',
#  'Loft 2',
#  'Loft 3',
#  'Entrance Hall 3',
#  'Pool 4',
#  'Family/TV Room 4',
#  'Entrance Hall 4',
#  'Special Features 12',
#  'Lease Period']

# %%
df.drop(columns=cols_to_drop, inplace=True)
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Listing Number - 0%
# Type of Property - 0%
# Listing Date - 0%
# Erf Size - 29%
# Pets Allowed - 45%
# Bedrooms - 8%
# Bathrooms - 14%
# Kitchens - 67%
# Dining Rooms - 80%
# Parking - 45%
# Bedroom 1 - 61%
# Bedroom 2 - 61%
# Bedroom 3 - 71%
# Bathroom 1 - 73%
# Bathroom 2 - 74%
# Kitchen - 51%
# Lounge - 65%
# Garden - 62%
# Pool - 72%
# Security - 53%
# Floor Size - 44%
# Levies - 60%
# Rates and Taxes - 31%
# Lounges - 72%
# Rooms - 90%
# Garage - 44%
# Internet Access - 87%
# Street Address - 63%
# Description - 78%
# Lifestyle - 82%
# Price per m� - 76%
# Bathroom - 89%
# Nearby Public Transport - 87%
# Bedroom 4 - 87%
# Bathroom 3 - 89%
# Domestic Rooms - 88%
# Reception Rooms - 85%
# Dining Room - 73%
# Family/TV Room - 87%
# Entrance Hall - 90%
# Outbuilding - 90%
# Special Features - 86%
# Special Feature - 88%
# Coverage - 89%
# Style - 87%
# Facing - 88%
# Roof - 84%
# Wall - 83%
# Window - 86%
# Standalone Building - 86%
# Garage 1 - 90%
# Garage 2 - 90%
# Flatlet - 90%
# Gardens - 87%

# %%
df['Bedrooms'] = pd.to_numeric(df.Bedrooms, errors='coerce')

# %%
med = df['Bedrooms'].median()
print(med)
df['Bedrooms'] = df['Bedrooms'].fillna(med)
# Out:
# 3.0

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].astype(str).str.isnumeric())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Listing Number - 100%
# Type of Property - 0%
# Listing Date - 0%
# Erf Size - 0%
# Pets Allowed - 0%
# Bedrooms - 88%
# Bathrooms - 66%
# Kitchens - 29%
# Dining Rooms - 13%
# Parking - 36%
# Bedroom 1 - 0%
# Bedroom 2 - 0%
# Bedroom 3 - 0%
# Bathroom 1 - 0%
# Bathroom 2 - 0%
# Kitchen - 5%
# Lounge - 6%
# Garden - 3%
# Pool - 2%
# Security - 3%
# Floor Size - 0%
# Levies - 0%
# Rates and Taxes - 0%
# Lounges - 20%
# Rooms - 0%
# Garage - 45%
# Internet Access - 0%
# Street Address - 0%
# Description - 0%
# Lifestyle - 0%
# Price per m� - 0%
# Bathroom - 0%
# Nearby Public Transport - 0%
# Bedroom 4 - 0%
# Bathroom 3 - 0%
# Domestic Rooms - 10%
# Reception Rooms - 0%
# Dining Room - 5%
# Family/TV Room - 3%
# Entrance Hall - 2%
# Outbuilding - 1%
# Special Features - 0%
# Special Feature - 0%
# Coverage - 0%
# Style - 0%
# Facing - 0%
# Roof - 0%
# Wall - 0%
# Window - 0%
# Standalone Building - 0%
# Garage 1 - 0%
# Garage 2 - 0%
# Flatlet - 0%
# Gardens - 11%

# %%
df['Bedrooms']
# Out:
# 0        3.0
# 1        3.0
# 2        3.0
# 3        2.0
# 4        2.0
#         ...
# 14924    3.0
# 14925    3.0
# 14926    3.0
# 14927    3.0
# 14928    4.0
# Name: Bedrooms, Length: 14929, dtype: float64
