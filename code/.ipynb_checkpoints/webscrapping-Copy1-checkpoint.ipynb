# %%
import requests
import numpy as np
import csv
from bs4 import BeautifulSoup

# %%
class ScraperApi:
    
    def __init__(self,url):
        _key = "a4c71eae23d6cc5d97ccd54d4d4e53c8"
        self.key = _key
        self.url_scraper ="http://api.scraperapi.com?api_key=" + self.key + "&url=" + url
        print(self.url_scraper)
        
    def getSoup(self):
        response = requests.get(self.url_scraper)
        
        if response.status_code != 200:
            print('Error with your request: ' + str(response.status_code))
        
        else:
            print('there is a response')
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup

# %%
class ScrapingBee:
    def __init__(self, url_site):
        
        # mamorina compte scrapingBee @gmail dia alaina iny key iny dia apetaka eto dia mandeha
        
        key = "9G9UA49KMOZT46FW014R726HPDYT3BSQU7HXRWGB3ZFNH4OZDUIMEQPMKWLMSOL4J8Z6I836OXCFXD0E"
        self.SCRAPINGBEE_API_KEY = key
        self.endpoint = "https://app.scrapingbee.com/api/v1"
        self.params = {
            'api_key': self.SCRAPINGBEE_API_KEY,
            'url': url_site,
            'render_js': 'false', 
        }
        
        self.url_site = url_site
        
        self.page = requests.get(self.url_site)
        
    def getSoup(self):
        response = requests.get(self.endpoint, params=self.params)
        
        if response.status_code != 200:
            print('Error with your request: ' + str(response.status_code))
        
        else:
            print('there is a response')
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup
        
    def getSoupTraditionnal(self):
        soup = BeautifulSoup(self.page.content,'html.parser')
        return soup
        
        
class FileCsv:
    
    def __init__(self, _path):
        self.path = _path
        
    def setHeader(self,header):
        with open(self.path, 'w') as f:
            writer = csv.writer(f)
            writer.writerow(header)
        
    def addColumn(self, row):
        with open(self.path, 'a') as f:
            writer = csv.writer(f)
            writer.writerow(row)
            
    def read(self, _path):
        with open(_path,'r') as f:
            spamreader = csv.reader(f, delimiter=',')
            for row in spamreader:
                print(row)

# %%
# scraping a page with all details
    
class ScrapingHouse:
    
    def __init__(self,url_house):
        self.url = url_house
        
        sb = ScraperApi(url_house)
        self.soup = sb.getSoup()

        self.features = {
            'page' : 0,
            'features' : [],
            'values' : []
        }
        self.path = ""
        
        self.liensVille = []
        
    def getData(self):
        
        if self.soup:
            
            features = self.soup.find_all('div',class_='p24_propertyOverviewKey')
            datas = self.soup.find_all('div',class_='p24_info')
            div_price = self.soup.find_all('div',class_="p24_mBM")
            
            if features and datas and div_price:
                
                price = div_price[0].find_all('div','p24_price')[0].text 
                
                for i in range(np.shape(datas)[0]):
                    self.features['values'].append(datas[i].text)
                    features = datas[i].parent.parent.div.text
                    self.features['features'].append(features)

                self.features['features'].append('price')
                self.features['values'].append(price)


                # adding the adress if exist

                a = self.soup.find('a',class_="p24_addressPropOverview")

                if a:
                    adress = a.text
                    features_adress = a.parent.parent.div.text
                    self.features['features'].append(features_adress)
                    self.features['values'].append(adress)

        print(self.features)
        
        
            
#         for i in range(np.shape(features)[0]):
# #             self.features['features'].append(features[i].text)
#             print(features[i].text)
    
#         print('--------------')
        
#         for i in range(np.shape(datas)[0]):
#             print(datas[i].text)
            
#         print(self.features)
        
#         for i in range(np.shape(datas)[0]):
#             self.features['values'].append(datas[i].text)
            
        return self.features
    
    def saveData(self,page):
        
        file = FileCsv('../data/house_price/' + page + '.csv')
        file.setHeader(self.features['features'])
        file.addColumn(self.features['values'])

# %%
class ScrapingProvince:
    
    def __init__(self,url_prov):
        self.url_page = []
        self.nb_page = 0
        self.page = requests.get(url_prov)
        self.url_prov = url_prov
    
    def findUrlPage(self):
        sb = ScraperApi(self.url_prov)
        soup = sb.getSoup()
#         print(soup)
        
        ul_pagination = soup.find_all("ul",class_="pagination")
        li = ul_pagination[0].find_all("li")

        last_page = int(li[np.shape(li)[0]-1].a.get('data-pagenumber'))
        
        for i in range(last_page):
            split = self.url_prov.split('?')

            split[0] += '/p' + str(i+1) + '?'
            url = split[0] + split[1]
            self.url_page.append(url)
            
        print(self.url_page)
            
        return self.url_page
        
    def saveUrl(self,province):
        file = FileCsv('../data/province/page/' + province + '.csv')
        file.setHeader(self.features['features'])
        file.addColumn(self.features['values'])

# %%
class ScrapingPage:
    
    def __init__(self,url_page):
        self.url_page = url_page
        self.soup = ScraperApi(url_page).getSoup()
        self.url_house = []
        
    def getAllUrlHouse(self):
        soup = self.soup
        div_container = soup.find_all('div','p24_regularTile')
        list_href = []
        
        for i in range(np.shape(div_container)[0]):
             list_href.append('https://www.property24.com' + div_container[i].a.get('href'))
        
        self.url_house = list_href
        
        print(self.url_house)
        
        return self.url_house

# %%
class Site:
    def __init__(self, url):
        self.url = url
        self.url_ville = []
        self.url_page_ville = []  # ato misy lien ana page bdb
        self.list_url_house = []
        self.url_page = []
        
    def findUrlVille(self):
#         soup = ScrapingBee(self.url).getSoupTraditionnal()
        
        soup = ScraperApi(self.url).getSoup() 
        
        div = soup.find_all('div',class_='p24_popular')
        
        file = FileCsv('../data/ville/url_ville.csv')
        file.setHeader(['url_ville'])
        
        for i in range(np.shape(div)[0]):
            a = div[i].find_all('a')
            for j in range(np.shape(a)[0]):
                if j== np.shape(a)[0]-3:
                    break
                else:
                    url = 'https://www.property24.com'+ a[j].get('href') + '?PropertyCategory=House%2cApartmentOrFlat'
                    self.url_ville.append(url)
                    file.addColumn([url])
        
    # prend en parametre un tableau d'url_ville et le parcours pour obtenir les liens_de son page
    # liens des (1......5689)
    
    def findUrlPageVille(self, url_ville):
        
        url_page = []
        
        for i in range(np.shape(url_ville)[0]):
            
            sp = ScrapingProvince(url_ville[i])
            url_page_one = sp.findUrlPage()
            url_page.append(url_page_one)
            self.url_page = url_page[0]
        
    def getContentPageVille(self,name_file):  # maka ny lien an'ilay house ao anaty ilay page
        
        file = FileCsv('../data/house_price/house_' + name_file + '.csv')
        file.setHeader(['data_house'])
        
        for i in range(np.shape(self.url_page)[0]):
            sp = ScrapingPage(self.url_page[i])
            
            allUrlHouse = sp.getAllUrlHouse()
            
            for j in range(np.shape(allUrlHouse)[0]):
                self.getDataHouse(allUrlHouse[j],file)
                print('ok j')
    
    def getDataHouse(self,url_house,file):
        
        print(url_house)
        
        sh = ScrapingHouse(url_house)
        features = sh.getData()
        
        file.addColumn(features['features'])
        file.addColumn(features['values'])

# %%
site= Site('https://www.property24.com')
print ('ok')
# --- atao valeur an'io tableau io ilay lien ana province tiana ho alaina dia mahazo ny house rehetra ao aminy--
# --- 

lien_province_tiana_alaina = 'https://www.property24.com/for-sale/randburg/gauteng/8?PropertyCategory=House%2cApartmentOrFlat'
url_ville = [lien_province_tiana_alaina]

site.findUrlPageVille(url_ville)

# ovana ilay name_file dia ville no aloha dia province no farany, raha /mabopane/gauteng izany ilay lien ohatra dia lasa
# mabopane_gauteng ilay fichier istoquer-na anazy

name_file = "randburg_gauteng"
site.getContentPageVille(name_file)
# Out:
# ok
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/randburg/gauteng/8?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ['https://www.property24.com/for-sale/randburg/gauteng/8/p1?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p2?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p3?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p4?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p5?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p6?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p7?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p8?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p9?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p10?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p11?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p12?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p13?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p14?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p15?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p16?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p17?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p18?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p19?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p20?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p21?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p22?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p23?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p24?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p25?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p26?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p27?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p28?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p29?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p30?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p31?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p32?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p33?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p34?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p35?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p36?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p37?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p38?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/randburg/gauteng/8/p39?PropertyCategory=House%2cApartment ...
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/randburg/gauteng/8/p1?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# ['https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110280359', 'https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110280251', 'https://www.property24.com/for-sale/cresta/randburg/gauteng/4404/110280236', 'https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110279917', 'https://www.property24.com/for-sale/sharonlea/randburg/gauteng/4296/110279807', 'https://www.property24.com/for-sale/cedar-lakes/randburg/gauteng/5210/110279117?plId=839342&plt=4', 'https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110279538', 'https://www.property24.com/for-sale/fairland/randburg/gauteng/4545/110276735', 'https://www.property24.com/for-sale/lanseria/randburg/gauteng/1020/110275210?plId=839113&plt=4', 'https://www.property24.com/for-sale/northwold/randburg/gauteng/4282/110266149', 'https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110033103', 'https://www.property24.com/for-sale/sundowner/randburg/gauteng/4298/110262854', 'https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110260554', 'https://www.property24.com/for-sale/sundowner/randburg/gauteng/4298/110262858', 'https://www.property24.com/for-sale/randpark-ridge/randburg/gauteng/4471/110259973', 'https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110267544']
# https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110280359
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110280359
# Error with your request: 500
# {'page': 0, 'features': [], 'values': []}
# ok j
# https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110280251
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110280251
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Furnished', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Bathroom 3', 'Kitchen', 'Lounge', 'Dining Room', 'Parking', 'Garden', 'Standalone Building', 'Security', 'Internet Access', 'Wheelchair Accessible', 'price', 'Street Address'], 'values': ['110280251', 'Apartment / Flat', 'Ground Floor', 'River frontage, Security Complex, Mountain', '08 August 2021', '133 m²', 'R 14 887', 'R 4 000', 'R 1 000', 'Yes', 'Optional', '3', 'Carpets, Balcony, Air Conditioner, Blinds, Curtain Rails, Fan, Built-in Cupboards, King Bed, Strong Room', 'Carpets, Balcony, Air Conditioner, Curtain Rails, Built-in Cupboards, King Bed', 'Carpets, Air Conditioner, Curtain Rails, Fan, Open Plan, Built-in Cupboards, Double Bed, Strong Room', '3', 'Tiled Floors, Blinds, Curtain Rails, Bath, Toilet and Basin', 'Tiled Floors, Shower, Toilet and Basin', 'Tiled Floors, Blinds, Curtain Rails, Bath, Toilet and Basin', 'Breakfast Nook, Open Plan, Pantry, Scullery, Stove, Extractor Fan, Fridge, Dishwasher Connection, Granite Tops, Washing Machine Connection, Tiled Floors, Air Conditioner, Curtain Rails, Open Plan, Built-in Cupboards, Under Counter Oven', 'Tiled Floors, Balcony, Air Conditioner, Curtain Rails, Open Plan', 'Tiled Floors, Air Conditioner, Open Plan', 'Visitors Parking, Carport, Secure Parking', 'Communal, Landscaped', 'No', 'Totally Fenced, Electric Gate, Security Gate, 24 Hour Response, Intercom, Closed Circuit TV, Burglar Bars, 24 Hour Access, Guard House, Guard, Electric fencing, Perimeter Wall, Safe', 'Fibre', 'No', 'R 1 980 000', " World's View, 13 Rockey Drive, Northcliff"]}
# ok j
# https://www.property24.com/for-sale/cresta/randburg/gauteng/4404/110280236
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/cresta/randburg/gauteng/4404/110280236
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Bedrooms', 'Bedroom 1', 'Bedroom 1', 'Bedroom 2', 'Bedroom 2', 'Bedroom 3', 'Bedroom 3', 'Bedroom 4', 'Bedroom 4', 'Bathrooms', 'Bathroom 1', 'Bathroom 1', 'Bathroom 2', 'Bathroom 2', 'Kitchen', 'Kitchen', 'Domestic Rooms', 'Lounge', 'Lounge', 'Dining Room', 'Dining Room', 'Other', 'Other', 'Parking', 'Parking 1', 'Parking 1', 'Parking 2', 'Parking 2', 'Parking 3', 'Parking 3', 'Secure Parking', 'Garden', 'Garden', 'Outbuildings', 'Outbuilding 1', 'Outbuilding 1', 'Outbuilding 2', 'Outbuilding 2', 'Outbuilding 3', 'Outbuilding 3', 'Outbuilding 4', 'Outbuilding 4', 'Security', 'Security', 'Security', 'price'], 'values': ['110280236', 'House', '08 August 2021', '4', 'Bedroom 1', 'Curtain Rails, TV Port', 'Bedroom 2', 'Parquet Floors, Curtain Rails', 'Bedroom 3', 'Parquet Floors, Curtain Rails', 'Bedroom 4', 'Tiled Floors, Curtain Rails, Internet Port', '2', 'Bathroom 1', 'Basin, En suite, Toilet', 'Bathroom 2', 'Basin, Bath', 'Kitchen', 'Breakfast Nook, Scullery, Granite Tops, Open Plan, Gas Hob', '1', 'Lounge', 'Tiled Floors, Curtain Rails, TV Port, Open Plan', 'Dining Room', 'Tiled Floors, Blinds, Open Plan', 'Office Flatlet Second House', 'Bath, Garden Services, Toilet', '3', 'Parking 1', 'Carport, Secure Parking', 'Parking 2', 'Carport, Secure Parking', 'Parking 3', 'Carport, Secure Parking', '3', 'Garden', 'Immaculate Condition, Landscaped', '4', 'Outbuilding 1', 'Staff Quarters/Domestic Rooms, Workshop', 'Outbuilding 2', 'Storeroom', 'Outbuilding 3', 'Storeroom', 'Outbuilding 4', 'Workshop, Outside Toilets', 'Security', 'Electric Gate, Intercom, Burglar Bars', 'Electric Gate, Intercom, Burglar Bars', 'R 2 350 000']}
# ok j
# https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110279917
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110279917
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Floor Number', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bathroom', 'Kitchen', 'Lounge', 'Garage', 'Pool', 'Facing', 'Standalone Building', 'Number of floors', 'Security', 'Temperature Controls', 'Internet Access', 'Wheelchair Accessible', 'Generator', 'price'], 'values': ['110279917', 'Apartment / Flat', 'Second floor and above', 'Complex', '07 August 2021', '91 m²', 'R 13 132', 'R 2 400', 'R 854', 'Yes', '2', '2', 'Carpets, Balcony, Blinds, Built-in Cupboards, King Bed', 'Carpets, Blinds, Built-in Cupboards, Queen Bed', 'Tiled Floors, Shower, Toilet and Basin', 'Open Plan, Stove (Oven & Hob), Dishwasher Connection, Granite Tops, Washing Machine Connection, Tiled Floors, Built-in Cupboards, Centre Island', 'Tiled Floors, Blinds, Curtain Rails, Veranda', '2', 'Rock Pool', 'Above Road', 'No', '3', 'Totally Fenced, Security Gate, Burglar Bars, Guard, Electric fencing, Perimeter Wall', '1', 'Fibre', 'No', 'No', 'R 1 195 000']}
# ok j
# https://www.property24.com/for-sale/sharonlea/randburg/gauteng/4296/110279807
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/sharonlea/randburg/gauteng/4296/110279807
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Kitchen', 'Office/study', 'Domestic Rooms', 'Lounge', 'Dining Room', 'Braai Room', 'Rooms', 'Garage', 'Garage 1', 'Garage 2', 'Parking', 'Garden', 'Pool', 'Security', 'Special Feature', 'Wheelchair Accessible', 'price', 'Street Address'], 'values': ['110279807', 'House', '07 August 2021', '1 350 m²', '230 m²', 'No', '3', ' ', ' ', ' ', '2', ' ', ' ', '1', ' ', ' ', ' ', 'Patio', '2', ' ', ' ', '2', 'Yes', 'Yes', 'Burglar Bars', 'Built in Braai', 'Yes', 'R 2 100 000', ' 26 Chamfuti Street, Sharonlea']}
# ok j
# https://www.property24.com/for-sale/cedar-lakes/randburg/gauteng/5210/110279117?plId=839342&plt=4
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/cedar-lakes/randburg/gauteng/5210/110279117?plId=839342&plt=4
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Levies', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Domestic Rooms', 'Lounges', 'Dining Rooms', 'Garage', 'Garden', 'Pool', 'price'], 'values': ['110279117', 'House', '07 August 2021', '428 m²', 'R 3 188', 'Yes', '3', '2', '1', '1', '1', '1', '2', 'Yes', 'Yes', 'R 3 800 000']}
# ok j
# https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110279538
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110279538
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Kitchen', 'Lounge', 'Dining Room', 'Rooms', 'Parking', 'Parking', 'Parking', 'Garden', 'Pool', 'Security', 'Security', 'price', 'Street Address'], 'values': ['110279538', 'Apartment / Flat', '07 August 2021', '172 m²', '117 m²', 'R 14 388', 'R 1 521', 'R 761', 'Yes', '3', '2', 'En suite', 'Laundry', '1', '1', 'Patio', '2', '2', '', '1', '1', '1', 'Security Gate, 24 Hour Access', 'R 1 683 400', '176 Canvas Road End, North Riding']}
# ok j
# https://www.property24.com/for-sale/fairland/randburg/gauteng/4545/110276735
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/fairland/randburg/gauteng/4545/110276735
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Kitchens', 'Kitchens', 'Parking', 'Secure Parking', 'Pool', 'Roof', 'Wall', 'Security', 'Special Feature', 'price', 'Street Address'], 'values': ['110276735', 'Apartment / Flat', 'Security Complex', '06 August 2021', '1 018 m²', '66 m²', 'R 11 515', 'R 1 022', 'R 306', '2', '1', 'Basin, Bath, Shower, Toilet', '1', 'Open Plan, Laundry, Under Counter Oven, Hob', '1', '1', 'Yes', 'Tile', 'Face-brick', 'Security Gate', 'Communal braai area', 'R 760 000', '82 Smit Street, Fairland']}
# ok j
# https://www.property24.com/for-sale/lanseria/randburg/gauteng/1020/110275210?plId=839113&plt=4
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/lanseria/randburg/gauteng/1020/110275210?plId=839113&plt=4
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Levies', 'Rates and Taxes', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Bathroom 3', 'Bathroom 4', 'Office/studies', 'Office 1', 'Office 2', 'Domestic Bathrooms', 'Lounges', 'Dining Room', 'Family/TV Room', 'Entrance Halls', 'Garage', 'Garage 1', 'Garage 2', 'Parking', 'Garden', 'Pools', 'Outbuildings', 'Outbuilding 1', 'Outbuilding 2', 'Outbuilding 3', 'Outbuilding 4', 'Outbuilding 5', 'Outbuilding 6', 'Outside Toilets', 'Security', 'Temperature Control', 'Special Features', 'Nearby Public Transport', 'price'], 'values': ['110275210', 'House', '06 August 2021', '1.83 ha', 'R 3 050', 'R 3 665', '3', 'Curtain Rails, Walk-in-closet, King Bed, Laminated Floors', 'Built-in Cupboards', 'Air Conditioner, Curtain Rails, Built-in Cupboards', '3.5', 'Basin, Guest Toilet', 'Shower, Toilet and Basin', 'Bath, Shower, Double Basin, En suite, Toilet', 'Main en Suite, Bath, Shower, Double Basin, Toilet', '2', 'Blinds', 'Under Floor Heating, Patio, Air Conditioner, Blinds, Internet Port', '1', '2', 'Curtain Rails, Open Plan', 'Curtain Rails, Telephone Port', '1', '2', 'Double, Electric Door', 'Double, Electric Door', '4', 'Courtyard', '1', '6', 'Outside Toilets', 'Domestic Bathroom', 'Pool Shed', 'Storeroom', 'Storeroom', 'Storeroom', '1', 'Totally Fenced, Electric Garage, Electric Gate, Guard House, Guard, Electric fencing', 'Air Conditioning Unit, Under Floor Heating', 'Driveway, Wallpaper', 'Bus, Minibus Taxi', 'R 7 995 000']}
# ok j
# https://www.property24.com/for-sale/northwold/randburg/gauteng/4282/110266149
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/northwold/randburg/gauteng/4282/110266149
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Reception Rooms', 'Lounge', 'Garage', 'Garden', 'Pool', 'price', 'Street Address'], 'values': ['110266149', 'House', '04 August 2021', '342 m²', '160 m²', 'R 1 700', 'R 900', 'Yes', '3', '3', '2', '2 Lounge', '2', 'Yes', 'Yes', 'R 1 980 000', '23 Maple Road, Northwold']}
# ok j
# https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110033103
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/north-riding/randburg/gauteng/4455/110033103
# there is a response
# {'page': 0, 'features': [], 'values': []}
# ok j
# https://www.property24.com/for-sale/sundowner/randburg/gauteng/4298/110262854
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/sundowner/randburg/gauteng/4298/110262854
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Kitchens', 'Kitchens', 'Reception Rooms', 'Garage', 'Security', 'Special Feature', 'price', 'Street Address'], 'values': ['110262854', 'House', '03 August 2021', '1 262 m²', '210 m²', 'R 717', '3', '2', 'Basin, Main en Suite, Bath, Shower, Toilet', '1', 'Extractor Fan, Under Counter Oven, Hob', '2', '2', 'Alarm System, Burglar Bars', 'Solar Geyser, Built in Bar', 'R 1 685 000', '86 Taurus Road, Sundowner']}
# ok j
# https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110260554
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/northcliff/randburg/gauteng/5783/110260554
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Listing Date', 'Erf Size', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedroom', 'Bathrooms', 'Kitchens', 'Kitchens', 'Garage', 'Parking', 'Garden', 'Pool', 'Facing', 'Roof', 'Wall', 'Security', 'Special Feature', 'price', 'Street Address'], 'values': ['110260554', 'Apartment / Flat', 'Single Storey', '03 August 2021', '6 467 m²', '49 m²', 'R 13 265', 'R 1 029', 'R 195', 'Yes', '1', '1', '1', 'Open Plan, Under Counter Oven, Hob', '1', '1', 'Yes', 'Yes', 'Mountain View', 'Tile', 'Plaster', 'Security Gate', 'Communal braai area', 'R 650 000', '74 Washington Drive, Northcliff']}
# ok j
# https://www.property24.com/for-sale/sundowner/randburg/gauteng/4298/110262858
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/sundowner/randburg/gauteng/4298/110262858
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Kitchens', 'Kitchens', 'Reception Rooms', 'Garage', 'Garden', 'Pool', 'Security', 'Special Feature', 'price', 'Street Address'], 'values': ['110262858', 'House', '03 August 2021', '1 040 m²', '360 m²', 'R 1 239', 'Yes', '4', '3', 'Basin, Main en Suite, Bath, Shower, Toilet', '1', 'Open Plan, Scullery, Extractor Fan, Granite Tops, Under Counter Oven', '2', '2', 'Yes', 'Yes', 'Alarm System, Burglar Bars', 'Built in Braai, Solar Geyser', 'R 2 595 000', '7 Orion Avenue, Sundowner']}
# ok j
# https://www.property24.com/for-sale/randpark-ridge/randburg/gauteng/4471/110259973
# http://api.scraperapi.com?api_key=00656fccfab43d70ab7224c8865626ba&url=https://www.property24.com/for-sale/randpark-ridge/randburg/gauteng/4471/110259973
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-e9bcad9700df> in <module>
#      13
#      14 name_file = "randburg_gauteng"
# ---> 15 site.getContentPageVille(name_file)
#
# <ipython-input-7-e5c754148019> in getContentPageVille(self, name_file)
#      52
#      53             for j in range(np.shape(allUrlHouse)[0]):
# ---> 54                 self.getDataHouse(allUrlHouse[j],file)
#      55                 print('ok j')
#      56
#
# <ipython-input-7-e5c754148019> in getDataHouse(self, url_house, file)
#      59         print(url_house)
#      60
# ---> 61         sh = ScrapingHouse(url_house)
#      62         features = sh.getData()
#      63
#
# <ipython-input-4-715626d78210> in __init__(self, url_house)
#       7
#       8         sb = ScraperApi(url_house)
# ----> 9         self.soup = sb.getSoup()
#      10
#      11         self.features = {
#
# <ipython-input-2-a644b3ffaed8> in getSoup(self)
#       8
#       9     def getSoup(self):
# ---> 10         response = requests.get(self.url_scraper)
#      11
#      12         if response.status_code != 200:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
sh = ScrapingHouse("https://www.property24.com/for-sale/blue-hills-country-estate/midrand/gauteng/12992/110279545")
sh.getData()
# Out:
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/blue-hills-country-estate/midrand/gauteng/12992/110279545
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Levies', 'No Transfer Duty', 'Rates and Taxes', 'price', 'Street Address'], 'values': ['110279545', 'Vacant Land / Plot', '07 August 2021', '5 049 m²', 'R 4 300', 'Yes', 'R 8 300', 'R 3 800 000', ' 1776 Blue Hills Equestrian Estate, Midrand, Blue Hills Country Estate']}
# {'page': 0,
#  'features': ['Listing Number',
#   'Type of Property',
#   'Listing Date',
#   'Erf Size',
#   'Levies',
#   'No Transfer Duty',
#   'Rates and Taxes',
#   'price',
#   'Street Address'],
#  'values': ['110279545',
#   'Vacant Land / Plot',
#   '07 August 2021',
#   '5 049 m²',
#   'R 4 300',
#   'Yes',
#   'R 8 300',
#   'R 3 800 000',
#   ' 1776 Blue Hills Equestrian Estate, Midrand, Blue Hills Country Estate']}
