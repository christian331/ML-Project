# %%
import requests
import numpy as np
import csv
from bs4 import BeautifulSoup

# %%
class ScraperApi:
    
    def __init__(self,url):
        _key = "1a18230ed0f817673163d7cc6d39e7bc"
        self.key = _key
        self.url_scraper ="http://api.scraperapi.com?api_key=" + self.key + "&url=" + url
        print(self.url_scraper)
        
    def getSoup(self):
        response = requests.get(self.url_scraper)
        
        if response.status_code != 200:
            print('Error with your request: ' + str(response.status_code))
        
        else:
            print('there is a response')
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup

# %%
class ScrapingBee:
    def __init__(self, url_site):
        
        # mamorina compte scrapingBee @gmail dia alaina iny key iny dia apetaka eto dia mandeha
        
        key = "9G9UA49KMOZT46FW014R726HPDYT3BSQU7HXRWGB3ZFNH4OZDUIMEQPMKWLMSOL4J8Z6I836OXCFXD0E"
        self.SCRAPINGBEE_API_KEY = key
        self.endpoint = "https://app.scrapingbee.com/api/v1"
        self.params = {
            'api_key': self.SCRAPINGBEE_API_KEY,
            'url': url_site,
            'render_js': 'false', 
        }
        
        self.url_site = url_site
        
        self.page = requests.get(self.url_site)
        
    def getSoup(self):
        response = requests.get(self.endpoint, params=self.params)
        
        if response.status_code != 200:
            print('Error with your request: ' + str(response.status_code))
        
        else:
            print('there is a response')
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup
        
    def getSoupTraditionnal(self):
        soup = BeautifulSoup(self.page.content,'html.parser')
        return soup
        
        
class FileCsv:
    
    def __init__(self, _path):
        self.path = _path
        
    def setHeader(self,header):
        with open(self.path, 'w') as f:
            writer = csv.writer(f)
            writer.writerow(header)
        
    def addColumn(self, row):
        with open(self.path, 'a') as f:
            writer = csv.writer(f)
            writer.writerow(row)
            
    def read(self, _path):
        with open(_path,'r') as f:
            spamreader = csv.reader(f, delimiter=',')
            for row in spamreader:
                print(row)

# %%
# scraping a page with all details
    
class ScrapingHouse:
    
    def __init__(self,url_house):
        self.url = url_house
        
        sb = ScraperApi(url_house)
        self.soup = sb.getSoup()

        self.features = {
            'page' : 0,
            'features' : [],
            'values' : []
        }
        self.path = ""
        
        self.liensVille = []
        
    def getData(self):
        
        if self.soup:
            
            features = self.soup.find_all('div',class_='p24_propertyOverviewKey')
            datas = self.soup.find_all('div',class_='p24_info')
            div_price = self.soup.find_all('div',class_="p24_mBM")
            
            if features and datas and div_price:
                
                price = div_price[0].find_all('div','p24_price')[0].text 
                
                for i in range(np.shape(datas)[0]):
                    self.features['values'].append(datas[i].text)
                    features = datas[i].parent.parent.div.text
                    self.features['features'].append(features)

                self.features['features'].append('price')
                self.features['values'].append(price)


                # adding the adress if exist

                a = self.soup.find('a',class_="p24_addressPropOverview")

                if a:
                    adress = a.text
                    features_adress = a.parent.parent.div.text
                    self.features['features'].append(features_adress)
                    self.features['values'].append(adress)

        print(self.features)
        
        
            
#         for i in range(np.shape(features)[0]):
# #             self.features['features'].append(features[i].text)
#             print(features[i].text)
    
#         print('--------------')
        
#         for i in range(np.shape(datas)[0]):
#             print(datas[i].text)
            
#         print(self.features)
        
#         for i in range(np.shape(datas)[0]):
#             self.features['values'].append(datas[i].text)
            
        return self.features
    
    def saveData(self,page):
        
        file = FileCsv('../data/house_price/' + page + '.csv')
        file.setHeader(self.features['features'])
        file.addColumn(self.features['values'])

# %%
class ScrapingProvince:
    
    def __init__(self,url_prov):
        self.url_page = []
        self.nb_page = 0
        self.page = requests.get(url_prov)
        self.url_prov = url_prov
    
    def findUrlPage(self):
        sb = ScraperApi(self.url_prov)
        soup = sb.getSoup()
#         print(soup)
        
        ul_pagination = soup.find_all("ul",class_="pagination")
        li = ul_pagination[0].find_all("li")

        last_page = int(li[np.shape(li)[0]-1].a.get('data-pagenumber'))
        
        for i in range(last_page):
            split = self.url_prov.split('?')

            split[0] += '/p' + str(i+1) + '?'
            url = split[0] + split[1]
            self.url_page.append(url)
            
        print(self.url_page)
            
        return self.url_page
        
    def saveUrl(self,province):
        file = FileCsv('../data/province/page/' + province + '.csv')
        file.setHeader(self.features['features'])
        file.addColumn(self.features['values'])

# %%
class ScrapingPage:
    
    def __init__(self,url_page):
        self.url_page = url_page
        self.soup = ScraperApi(url_page).getSoup()
        self.url_house = []
        
    def getAllUrlHouse(self):
        soup = self.soup
        div_container = soup.find_all('div','p24_regularTile')
        list_href = []
        
        for i in range(np.shape(div_container)[0]):
             list_href.append('https://www.property24.com' + div_container[i].a.get('href'))
        
        self.url_house = list_href
        
        print(self.url_house)
        
        return self.url_house

# %%
class Site:
    def __init__(self, url):
        self.url = url
        self.url_ville = []
        self.url_page_ville = []  # ato misy lien ana page bdb
        self.list_url_house = []
        self.url_page = []
        
    def findUrlVille(self):
#         soup = ScrapingBee(self.url).getSoupTraditionnal()
        
        soup = ScraperApi(self.url).getSoup() 
        
        div = soup.find_all('div',class_='p24_popular')
        
        file = FileCsv('../data/ville/url_ville.csv')
        file.setHeader(['url_ville'])
        
        for i in range(np.shape(div)[0]):
            a = div[i].find_all('a')
            for j in range(np.shape(a)[0]):
                if j== np.shape(a)[0]-3:
                    break
                else:
                    url = 'https://www.property24.com'+ a[j].get('href') + '?PropertyCategory=House%2cApartmentOrFlat'
                    self.url_ville.append(url)
                    file.addColumn([url])
        
    # prend en parametre un tableau d'url_ville et le parcours pour obtenir les liens_de son page
    # liens des (1......5689)
    
    def findUrlPageVille(self, url_ville):
        
        url_page = []
        
        for i in range(np.shape(url_ville)[0]):
            
            sp = ScrapingProvince(url_ville[i])
            url_page_one = sp.findUrlPage()
            url_page.append(url_page_one)
            self.url_page = url_page[0]
        
    def getContentPageVille(self,name_file):  # maka ny lien an'ilay house ao anaty ilay page
        
        file = FileCsv('../data/house_price/house_' + name_file + '.csv')
        file.setHeader(['data_house'])
        
        for i in range(np.shape(self.url_page)[0]):
            sp = ScrapingPage(self.url_page[i])
            
            allUrlHouse = sp.getAllUrlHouse()
            
            for j in range(np.shape(allUrlHouse)[0]):
                self.getDataHouse(allUrlHouse[j],file)
                print('ok j')
    
    def getDataHouse(self,url_house,file):
        
        print(url_house)
        
        sh = ScrapingHouse(url_house)
        features = sh.getData()
        
        file.addColumn(features['features'])
        file.addColumn(features['values'])

# %%
site= Site('https://www.property24.com')
print ('ok')
# --- atao valeur an'io tableau io ilay lien ana province tiana ho alaina dia mahazo ny house rehetra ao aminy--
# --- 

lien_province_tiana_alaina = 'https://www.property24.com/for-sale/mabopane/gauteng/76?PropertyCategory=House%2cApartmentOrFlat'
url_ville = [lien_province_tiana_alaina]

site.findUrlPageVille(url_ville)

# ovana ilay name_file dia ville no aloha dia province no farany, raha /mabopane/gauteng izany ilay lien ohatra dia lasa
# mabopane_gauteng ilay fichier istoquer-na anazy

name_file = "mabopane_gauteng"
site.getContentPageVille(name_file)
# Out:
# ok
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/pretoria/gauteng/1?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# ['https://www.property24.com/for-sale/pretoria/gauteng/1/p1?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p2?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p3?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p4?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p5?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p6?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p7?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p8?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p9?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p10?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p11?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p12?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p13?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p14?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p15?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p16?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p17?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p18?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p19?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p20?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p21?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p22?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p23?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p24?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p25?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p26?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p27?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p28?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p29?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p30?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p31?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p32?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p33?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p34?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p35?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p36?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p37?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p38?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/pretoria/gauteng/1/p39?PropertyCategory=House%2cApartment ...
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/pretoria/gauteng/1/p1?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# []
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/pretoria/gauteng/1/p2?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# ['https://www.property24.com/for-sale/annlin/pretoria/gauteng/4022/110280456', 'https://www.property24.com/for-sale/montana-tuine/pretoria/gauteng/4069/110280425', 'https://www.property24.com/for-sale/wonderboom-south/pretoria/gauteng/327/110006629', 'https://www.property24.com/for-sale/silverton/pretoria/gauteng/2958/110280418', 'https://www.property24.com/for-sale/daspoort-estate/pretoria/gauteng/282/110280371', 'https://www.property24.com/for-sale/wonderboom-south/pretoria/gauteng/327/110280343', 'https://www.property24.com/for-sale/blyde-riverwalk-estate/pretoria/gauteng/33014/110280262', 'https://www.property24.com/for-sale/pretoria-north/pretoria/gauteng/4076/110280235', 'https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110280229', 'https://www.property24.com/for-sale/lotus-gardens/pretoria/gauteng/2922/110280226', 'https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110280184', 'https://www.property24.com/for-sale/danville/pretoria/gauteng/2906/110280137', 'https://www.property24.com/for-sale/florauna/pretoria/gauteng/4052/110280092', 'https://www.property24.com/for-sale/wapadrand/pretoria/gauteng/127/110280089', 'https://www.property24.com/for-sale/christiaanville-ah/pretoria/gauteng/4032/110280088', 'https://www.property24.com/for-sale/andeon-ah/pretoria/gauteng/33198/110279922', 'https://www.property24.com/for-sale/zwavelpoort-ah/pretoria/gauteng/164/110279888', 'https://www.property24.com/for-sale/mountain-view/pretoria/gauteng/290/110279872', 'https://www.property24.com/for-sale/clydesdale/pretoria/gauteng/28/110279871', 'https://www.property24.com/for-sale/elarduspark/pretoria/gauteng/3940/110279858']
# https://www.property24.com/for-sale/annlin/pretoria/gauteng/4022/110280456
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/annlin/pretoria/gauteng/4022/110280456
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Levies', 'Rates and Taxes', 'price', 'Street Address'], 'values': ['110280456', 'Apartment / Flat', '08 August 2021', 'R 1 700', 'R 409', 'R 770 000', ' 294 Marija Street, Annlin']}
# ok j
# https://www.property24.com/for-sale/montana-tuine/pretoria/gauteng/4069/110280425
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/montana-tuine/pretoria/gauteng/4069/110280425
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Lifestyle', 'Listing Date', 'Floor Size', 'Levies', 'No Transfer Duty', 'Pets Allowed', 'Standalone Building', 'price'], 'values': ['110280425', 'House', 'Security Complex, Security Estate', '08 August 2021', '134 m²', 'R 2 900', 'Yes', 'Yes', 'Yes', 'R 19 925 000']}
# ok j
# https://www.property24.com/for-sale/wonderboom-south/pretoria/gauteng/327/110006629
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/wonderboom-south/pretoria/gauteng/327/110006629
# there is a response
# {'page': 0, 'features': [], 'values': []}
# ok j
# https://www.property24.com/for-sale/silverton/pretoria/gauteng/2958/110280418
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/silverton/pretoria/gauteng/2958/110280418
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Price per m²', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Lounges', 'Parking', 'Garden', 'Pool', 'Pool', 'price', 'Street Address'], 'values': ['110280418', 'Apartment / Flat', '08 August 2021', '5 194 m²', '57 m²', 'R 7 895', 'R 347', 'No', '2', '1', '1', '1', '1', 'Yes', 'Yes', 'communal', 'R 450 000', '100 De Boulevard, Silverton']}
# ok j
# https://www.property24.com/for-sale/daspoort-estate/pretoria/gauteng/282/110280371
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/daspoort-estate/pretoria/gauteng/282/110280371
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Kitchen', 'Lounge', 'Dining Room', 'Family/TV Room', 'Braai Room', 'Rooms', 'Parking', 'Parking', 'Parking', 'Garden', 'Pool', 'Security', 'Special Feature', 'price'], 'values': ['110280371', 'House', 'Single Storey', '08 August 2021', '666 m²', 'R 500', 'Yes', '3', '2', 'En suite', '1', '1', '1', '1', '1', 'Patio', '4', '4', '', '1', '1', '24 Hour Access', 'Built in Braai, Borehole', 'R 1 257 000']}
# ok j
# https://www.property24.com/for-sale/wonderboom-south/pretoria/gauteng/327/110280343
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/wonderboom-south/pretoria/gauteng/327/110280343
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Levies', 'Rates and Taxes', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Kitchen', 'Parking', 'Garden', 'Nearby Public Transport', 'price'], 'values': ['110280343', 'Apartment / Flat', '08 August 2021', 'R 1 500', 'R 450', '2', 'Tiled Floors, Built-in Cupboards', 'Tiled Floors, Built-in Cupboards', '2', 'Bath, Toilet and Basin', 'Guest Toilet', 'Tiled Floors, Built-in Cupboards', 'Visitors Parking, Single', 'Courtyard', 'Bus, Minibus Taxi', 'R 620 000']}
# ok j
# https://www.property24.com/for-sale/blyde-riverwalk-estate/pretoria/gauteng/33014/110280262
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/blyde-riverwalk-estate/pretoria/gauteng/33014/110280262
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Kitchen', 'Lounge', 'Dining Room', 'Parking', 'Pool', 'Standalone Building', 'Number of floors', 'Security', 'Special Features', 'Internet Access', 'price', 'Street Address'], 'values': ['110280262', 'Apartment / Flat', 'First Floor', 'River frontage, Security Estate, Waterfront', '08 August 2021', '74 m²', 'R 25 000', 'R 2 137', 'R 600', 'Yes', '2', 'Tiled Floors, Blinds, Curtain Rails, Built-in Cupboards, Double Bed, Linen Room', 'Tiled Floors, Balcony, Blinds, Curtain Rails, Open Plan, Built-in Cupboards, Double Bed', '2', 'Tiled Floors, Main en Suite, Blinds, Curtain Rails, Open Plan, Shower, Toilet and Basin, Bath, Toilet and Basin', 'Tiled Floors, Full, Main en Suite, Blinds, Curtain Rails, Toilet', 'Open Plan, Pantry, Scullery, Stove, Extractor Fan, Fridge, Dishwasher Connection, Garbage Disposal, Granite Tops, Washing Machine Connection, Tiled Floors, Curtain Rails, Open Plan, Built-in Cupboards, Hob', 'Tiled Floors, Balcony, Open Plan', 'Tiled Floors, Balcony, Curtain Rails, Open Plan', 'Carport, Double', 'Chlorinator', 'No', '1', 'Totally Fenced, Electric Gate, Security Gate, 24 Hour Response, Intercom, Closed Circuit TV, 24 Hour Access, Guard House, Guard, Electric fencing, Perimeter Wall', 'Satellite Dish, Balcony, Open Plan, Communal braai area', 'Fibre', 'R 1 850 000', ' The Blyde, Blyde Riverwalk Estate']}
# ok j
# https://www.property24.com/for-sale/pretoria-north/pretoria/gauteng/4076/110280235
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/pretoria-north/pretoria/gauteng/4076/110280235
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Bedrooms', 'Bedroom 1', 'Bedroom 1', 'Bedroom 2', 'Bedroom 2', 'Bedroom 3', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 1', 'Bathroom 2', 'Bathroom 2', 'Kitchen', 'Kitchen', 'Dining Room', 'Dining Room', 'Family/TV Room', 'Family/TV Room', 'Other', 'Other', 'Garage', 'Garage', 'Garage', 'Parking', 'Parking 1', 'Parking 1', 'Parking 2', 'Parking 2', 'Gardens', 'Garden 1', 'Garden 2', 'Garden 2', 'price'], 'values': ['110280235', 'House', '08 August 2021', '800 m²', 'R 687', '3', 'Bedroom 1', 'Tiled Floors, Curtain Rails', 'Bedroom 2', 'Tiled Floors, Curtain Rails', 'Bedroom 3', 'Tiled Floors, Curtain Rails', '2', 'Bathroom 1', 'Basin, Bath, Shower, Toilet', 'Bathroom 2', 'Basin, Bath, Shower, En suite', 'Kitchen', 'Breakfast Nook, Open Plan, Gas Hob', 'Dining Room', 'Tiled Floors, Curtain Rails, Open Plan', 'Family T V Room', 'Tiled Floors, Curtain Rails, Open Plan', 'Office Flatlet Second House', 'Shower, Toilet', '2', 'Garage', 'Double', '2', 'Parking 1', 'Carport', 'Parking 2', 'Carport', '2', 'Garden 1', 'Garden 2', 'Landscaped', 'R 1 380 000']}
# ok j
# https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110280229
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110280229
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bedroom 4', 'Bedroom 5', 'Bedroom 6', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Bathroom 3', 'Kitchen', 'Office/study', 'Domestic Rooms', 'Reception Rooms', 'Dining Room', 'Entrance Hall', 'Other', 'Other 1', 'Other 2', 'Other 3', 'Other 4', 'Other 5', 'Other 6', 'Garage', 'price'], 'values': ['110280229', 'House', '08 August 2021', '1 184 m²', '520 m²', '6', 'Main bedroom with built-in cupboards, king bed, walk-in closet and carpeted floors', 'Bedroom 2 with built-in cupboards, double bed and carpeted floors', 'Bedroom 3 with built-in cupboards and carpeted floors', 'Bedroom 4 with built-in cupboards and carpeted floors', 'Bedroom 5 with built-in cupboards, double bed and carpeted floors', 'Bedroom 6 with built-in cupboards and double bed', '4', 'Bathroom 1 with basin, bath, bidet, shower, toilet and tiled floors', 'Bathroom 2 with basin, shower and toilet', 'Bathroom 3 with bath, double basin and toilet', 'Kitchen with tiled floors, wood finishes, dish-wash machine connection, dishwasher, extractor fan, gas, oven and hob, pantry, stove, under counter oven and washing machine', 'Study with wood strip floors', '1', '3', 'Dining room with tiled floors', 'Entrance hall with tiled floors', '6', 'Living room with gas fireplace and parquet floors', 'Guest cloakroom', 'Playroom', 'Storeroom', 'Scullery', 'Laundry', '3', 'R 6 200 000']}
# ok j
# https://www.property24.com/for-sale/lotus-gardens/pretoria/gauteng/2922/110280226
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/lotus-gardens/pretoria/gauteng/2922/110280226
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bathroom', 'Kitchen', 'Family/TV Room', 'Garage', 'Parking', 'Parking 1', 'Parking 2', 'Gardens', 'Roof', 'Wall', 'Window', 'Standalone Building', 'Security', 'Nearby Public Transport', 'price'], 'values': ['110280226', 'House', 'Freestanding', 'Suburban', '08 August 2021', '300 m²', '90 m²', 'R 750', 'Yes', '30 %', '2', 'Tiled Floors, Curtain Rails, Built-in Cupboards', 'Tiled Floors, Curtain Rails, Built-in Cupboards', 'Tiled Floors, Separate Toilet, Basin, Bath, Blinds', 'Extractor Fan, Tiled Floors, Blinds, Built-in Cupboards, Under Counter Oven', 'Tiled Floors, Curtain Rails, TV Port', '1', '2', 'Shade net covered', 'Visitors Parking', '1', 'Tile', 'Plaster', 'Steel ', 'Yes', 'Totally Fenced, Perimeter Wall', 'Minibus Taxi', 'R 850 000']}
# ok j
# https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110280184
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110280184
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Garage', 'Gardens', 'Security', 'Temperature Control', 'price'], 'values': ['110280184', 'House', '08 August 2021', '3', '2.5', '1', '2', '1', 'Electric Garage, 24 Hour Access, Guard, Boomed Area', 'Air Conditioning Unit', 'POA']}
# ok j
# https://www.property24.com/for-sale/danville/pretoria/gauteng/2906/110280137
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/danville/pretoria/gauteng/2906/110280137
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Lounge', 'Dining Room', 'Garage', 'Parking', 'Pool', 'price'], 'values': ['110280137', 'House', '08 August 2021', '684 m²', '3', '2', 'En suite', '1', '1', '2', '2', 'Yes', 'R 1 170 000']}
# ok j
# https://www.property24.com/for-sale/florauna/pretoria/gauteng/4052/110280092
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/florauna/pretoria/gauteng/4052/110280092
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Garage', 'Gardens', 'price'], 'values': ['110280092', 'House', '08 August 2021', '5 000 m²', '3', '2', '1', '2', '1', 'R 2 180 000']}
# ok j
# https://www.property24.com/for-sale/wapadrand/pretoria/gauteng/127/110280089
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/wapadrand/pretoria/gauteng/127/110280089
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Lifestyle', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 1', 'Bedroom 2', 'Bedroom 2', 'Bedroom 3', 'Bedroom 3', 'Bedroom 4', 'Bedroom 4', 'Bathrooms', 'Bathroom 1', 'Bathroom 1', 'Bathroom 2', 'Bathroom 2', 'Bathroom 3', 'Bathroom 3', 'Kitchen', 'Kitchen', 'Office/study', 'Office/study', 'Domestic Rooms', 'Lounge', 'Lounge', 'Dining Room', 'Dining Room', 'Braai Room', 'Braai Room', 'Entrance Hall', 'Rooms', 'Garage', 'Garage 1', 'Garage 1', 'Garage 2', 'Garage 2', 'Parking', 'Parking 1', 'Parking 2', 'Parking 3', 'Parking 4', 'Parking 5', 'Parking 6', 'Garden', 'Pool', 'Security', 'Special Feature', 'Flatlet', 'price'], 'values': ['110280089', 'House', 'Cul-de-sac', '08 August 2021', '1 264 m²', 'R 2 000', 'Yes', '4', 'Situated in the guest wing of the house this bedroom is actually part of a guest suite with an en-suite bathroom and separate living area opening up onto its own balcony', 'King Bed', "Same rustic feel as the whole house, with enough space for a queen size bed but perfect as a character filled, attic-feel child's room.", 'Built-in Cupboards, Double Bed', "Same rustic feel as the whole house, with enough space for a queen size bed but perfect as a character filled, attic-feel child's room.", 'Built-in Cupboards, Double Bed', 'The Main Bedroom. Rustic open plan with a classic country feel. Tiled floors', 'Walk-in-closet, King Bed', '3.5', 'Tiled open plan country feel', 'En suite, Shower, Toilet and Basin', 'Shared bathroom with tiled floors', 'Full', 'Beautifully completes the guest suit. Tiled floors with extractor fan', 'Full, En suite', 'Has to be seen to be appreciated. Semi open-plan with a bright breakfast table corner, separate scullery, a separate entrance to the formal dining area, flows out onto the outside covered patio and braai area. Country feel.', 'Breakfast Nook, Pantry, Scullery, Laundry, Extractor Fan, Fridge, Dishwasher Connection, Granite Tops, Washing Machine Connection, Tumble Dryer, Centre Island, Country Style, Gas Hob', 'Spacious with built in shelves and exposed brick feature wall.', 'Tiled Floors, Blinds, Internet Port', '1', 'Bright yet cozy lower level living area with high ceilings, characterized by the exposed beams mirrored throughout the house, frosted glass double volume windows letting lots of light in, frosted glass doors leading onto the spacious covered patio, overlooking the beautifully maintained garden and pool', 'Patio, Tiled Floors, Air Conditioner, Blinds, TV Port, Fireplace, Open Plan', 'Semi-Open plan dining area with a door leading into the kitchen and an open ingress to the lower level lounge.', 'Tiled Floors, Blinds, Open Plan', 'Built in braai on a beautifully designed and covered patio, with built in cupboards and down lights', 'Patio, Tiled Floors', ' ', 'Patio', '2', 'Spacious double garage with the workshop in an equally roomy and separate area to the back of it.', 'Double, Workshop', ' ', 'Double', '6', 'Secure Parking', 'Secure Parking', 'Secure Parking', 'Secure Parking', 'Secure Parking', 'Secure Parking', 'Yes', 'Yes', 'Alarm System, Electric fencing', 'Built in Braai', 'Yes', 'R 4 300 000']}
# ok j
# https://www.property24.com/for-sale/christiaanville-ah/pretoria/gauteng/4032/110280088
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/christiaanville-ah/pretoria/gauteng/4032/110280088
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Levies', 'Rates and Taxes', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Bathroom 3', 'Bathroom 4', 'Kitchen', 'Dining Room', 'Family/TV Room', 'Braai Room', 'Garage', 'Parking', 'Garden', 'Security', 'Nearby Public Transport', 'Internet Access', 'Wheelchair Accessible', 'Generator', 'price'], 'values': ['110280088', 'House', 'Double Storey, Freestanding', 'Security Estate, Suburban', '08 August 2021', '308 m²', 'R 1 040', 'R 852', '3', 'Air Conditioner, Blinds, Built-in Cupboards, Double Bed, Laminated Floors', 'Blinds, Built-in Cupboards, Queen Bed, Laminated Floors', 'Air Conditioner, Blinds, TV Port, Built-in Cupboards, Queen Bed, Laminated Floors', '4', 'Tiled Floors, Blinds, Shower, Toilet and Basin', 'Tiled Floors, Blinds, Shower, Toilet and Basin', 'Full, Main en Suite, Blinds, Double Basin', 'Guest Toilet', 'Breakfast Nook, Open Plan, Scullery, Eye Level Oven, Extractor Fan, Dishwasher Connection, Washing Machine Connection, Tiled Floors, Blinds, Open Plan, Built-in Cupboards, Centre Island, Gas Hob, Under Counter Oven', 'Patio, Tiled Floors, Blinds, Open Plan', 'Tiled Floors, Air Conditioner, Telephone Port, TV Port, Open Plan', 'Patio, Tiled Floors, Fireplace, Open Plan', 'Double, Electric Door', 'Double', 'Courtyard, Landscaped', 'Electric Garage, Security Gate, Alarm System, 24 Hour Response, Closed Circuit TV, 24 Hour Access, Guard House, Perimeter Wall, Safe', 'Minibus Taxi', 'Fibre', 'Yes', 'No', 'R 2 499 000']}
# ok j
# https://www.property24.com/for-sale/andeon-ah/pretoria/gauteng/33198/110279922
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/andeon-ah/pretoria/gauteng/33198/110279922
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Floor Size', 'No Transfer Duty', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Kitchen', 'price'], 'values': ['110279922', 'House', '07 August 2021', '65 m²', 'Yes', '3', 'Built-in Cupboards, King Bed', 'Built-in Cupboards, Queen Bed', 'Built-in Cupboards, Queen Bed', '2', 'Main en Suite, Bath, Toilet and Basin', 'Bath, Toilet and Basin', 'Stove (Oven & Hob), Built-in Cupboards', 'R 896 900']}
# ok j
# https://www.property24.com/for-sale/zwavelpoort-ah/pretoria/gauteng/164/110279888
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/zwavelpoort-ah/pretoria/gauteng/164/110279888
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bedroom 4', 'Bedroom 5', 'Bathrooms', 'Kitchen', 'Office/studies', 'Office 1', 'Office 2', 'Domestic Rooms', 'Lounge', 'Dining Room', 'Braai Room', 'Entrance Hall', 'Garage', 'Garage 1', 'Garage 2', 'Garage 3', 'Garage 4', 'Parking', 'Garden', 'Security', 'Flatlet', 'price'], 'values': ['110279888', 'House', 'Double Storey', 'Security Estate', '07 August 2021', '2 065 m²', '590 m²', 'R 3 420', 'R 3 257', 'Yes', '5', ' ', ' ', ' ', ' ', ' ', '4.5', ' ', '2', ' ', ' ', '1', ' ', ' ', ' ', ' ', '4', ' ', ' ', ' ', ' ', '4', 'Yes', 'Alarm System, Electric fencing', 'Yes', 'R 5 495 000']}
# ok j
# https://www.property24.com/for-sale/mountain-view/pretoria/gauteng/290/110279872
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mountain-view/pretoria/gauteng/290/110279872
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Pets Allowed', 'Bedrooms', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Reception Rooms', 'Pool', 'Flatlet', 'price'], 'values': ['110279872', 'House', '07 August 2021', '2 552 m²', 'Yes', '4', 'Main house has 4 bedrooms. Flatlets has 4 bedrooms', '2', 'Main house has 2 bathrooms. Flatlets has one ba...', '3', 'Yes', 'Yes', 'R 1 990 000']}
# ok j
# https://www.property24.com/for-sale/clydesdale/pretoria/gauteng/28/110279871
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/clydesdale/pretoria/gauteng/28/110279871
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Garage', 'Parking', 'price'], 'values': ['110279871', 'House', '07 August 2021', '3', '1', '1', '1', '1', 'R 1 970 000']}
# ok j
# https://www.property24.com/for-sale/elarduspark/pretoria/gauteng/3940/110279858
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/elarduspark/pretoria/gauteng/3940/110279858
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Bedrooms', 'Bedroom 1', 'Bedroom 1', 'Bedroom 2', 'Bedroom 2', 'Bathroom', 'Bathroom', 'Kitchen', 'Kitchen', 'Lounge', 'Lounge', 'Dining Room', 'Dining Room', 'Rooms', 'Parking', 'Garden', 'Garden', 'Pool', 'Pool', 'Security', 'Security', 'Security', 'Special Features', 'Special Features', 'Special Feature', 'price', 'Street Address'], 'values': ['110279858', 'Apartment / Flat', '07 August 2021', '65 m²', 'R 11 846', 'R 1 500', 'R 450', '2', 'Bedroom 1', 'Carpets, Curtain Rails', 'Bedroom 2', 'Carpets, Curtain Rails', 'Bathroom', 'Basin, Bath, Toilet', 'Kitchen', 'Breakfast Nook, Stove, Open Plan', 'Lounge', 'Patio, Tiled Floors, Curtain Rails, Open Plan', 'Dining Room', 'Tiled Floors, Open Plan', 'Patio', 'Parking', 'Garden', 'Communal', 'Pool', 'Fenced, Communal Pool', 'Security', 'Burglar Bars, Guard House, Guard, Perimeter Wall', 'Burglar Bars, Guard House, Guard, Perimeter Wall', 'Special Features', 'Patio, Driveway', 'Driveway', 'R 770 000', '81, 90 Miller Clary Street, Elarduspark']}
# ok j
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/pretoria/gauteng/1/p3?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# ['https://www.property24.com/for-sale/lombardy-estate/pretoria/gauteng/12172/110131093?plId=836585&plt=4', 'https://www.property24.com/for-sale/magalieskruin/pretoria/gauteng/4062/110274848', 'https://www.property24.com/for-sale/wonderboom/pretoria/gauteng/4089/110255886', 'https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110272182', 'https://www.property24.com/for-sale/willow-park-manor/pretoria/gauteng/132/110258446', 'https://www.property24.com/for-sale/zambezi-manor-lifestyle-estate/pretoria/gauteng/33015/110261302', 'https://www.property24.com/for-sale/garsfontein/pretoria/gauteng/140/110259031', 'https://www.property24.com/for-sale/waverley/pretoria/gauteng/3019/110260625', 'https://www.property24.com/for-sale/willow-park-manor/pretoria/gauteng/132/110237837', 'https://www.property24.com/for-sale/moreleta-park/pretoria/gauteng/10622/110271203', 'https://www.property24.com/for-sale/garsfontein/pretoria/gauteng/140/110261166', 'https://www.property24.com/for-sale/olympus-ah/pretoria/gauteng/12201/105115524', 'https://www.property24.com/for-sale/zwavelpoort-ah/pretoria/gauteng/164/110208347', 'https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110274843', 'https://www.property24.com/for-sale/hatfield/pretoria/gauteng/304/110248289', 'https://www.property24.com/for-sale/lombardy-estate/pretoria/gauteng/12172/110269329', 'https://www.property24.com/for-sale/sinoville/pretoria/gauteng/4080/110242006', 'https://www.property24.com/for-sale/montana-park/pretoria/gauteng/4070/110224025', 'https://www.property24.com/for-sale/sunnyside/pretoria/gauteng/41/110236583', 'https://www.property24.com/for-sale/kilner-park/pretoria/gauteng/3004/110273821', 'https://www.property24.com/for-sale/lombardy-estate/pretoria/gauteng/12172/110238638']
# https://www.property24.com/for-sale/lombardy-estate/pretoria/gauteng/12172/110131093?plId=836585&plt=4
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/lombardy-estate/pretoria/gauteng/12172/110131093?plId=836585&plt=4
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Age', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bedroom 1', 'Bedroom 1', 'Bedroom 2', 'Bedroom 2', 'Bedroom 3', 'Bedroom 3', 'Bedroom 4', 'Bedroom 4', 'Bedroom 5', 'Bedroom 5', 'Bathrooms', 'Bathroom 1', 'Bathroom 1', 'Bathroom 2', 'Bathroom 2', 'Bathroom 3', 'Bathroom 3', 'Bathroom 4', 'Bathroom 4', 'Bathroom 5', 'Bathroom 5', 'Kitchen', 'Kitchen', 'Office/study', 'Office/study', 'Domestic Rooms', 'Domestic Rooms', 'Dining Rooms', 'Dining Room 1', 'Dining Room 1', 'Dining Room 2', 'Family/TV Rooms', 'Family/TV Room 1', 'Family/TV Room 2', 'Family/TV Room 2', 'Bars', 'Bar 1', 'Bar 1', 'Bar 2', 'Entrance Hall', 'Entrance Hall', 'Other', 'Other', 'Garage', 'Garage 1', 'Garage 2', 'Garage 3', 'Garage 4', 'Garden', 'Pools', 'Pool 1', 'Pool 2', 'Outbuilding', 'Outbuilding', 'Style', 'Facing', 'Roof', 'Wall', 'Window', 'Standalone Building', 'Security', 'Temperature Control', 'Special Features', 'Nearby Public Transport', 'Internet Access', 'Wheelchair Accessible', 'Generator', 'Backup Water', 'price', 'Street Address'], 'values': ['110131093', 'House', 'Double Storey, Freestanding', 'Estate, Fishing Estate, Security Estate', '25 June 2021', '987 m²', '700 m²', 'R 2 701', 'R 3 240', '2', 'Yes', '70 %', '5', 'Top floor Master Bedroom ', 'Tiled Floors, Balcony, Air Conditioner, Fireplace, Built-in Cupboards, Walk-in-closet, King Bed', '2nd Top floor Bedroom ', 'Tiled Floors, Balcony, King Bed', '3rd Top floor Bedroom', 'Tiled Floors, Balcony, King Bed', '4th Top floor Bedroom', 'Tiled Floors, Balcony, King Bed', 'Ground floor Guest Bedroom', 'Tiled Floors, King Bed', '5', '2nd en-suite Bathroom', 'Bath, Toilet and Basin', '3rd en-suite Bathroom', 'Tiled Floors, Bath, Toilet and Basin', '4th en-suite Bathroom', 'Tiled Floors, Bath, Toilet and Basin', 'Guest en-suite Bathroom', 'Bath, Toilet and Basin', 'Master en-suite Bathroom', 'Tiled Floors, Jacuzzi Bath, Main en Suite, Bath, Toilet and Basin', 'Spacious open plan Kitchen, with breathtaking finishes.', 'Breakfast Nook, Open Plan, Pantry, Scullery, Laundry, Eye Level Oven, Extractor Fan, Dishwasher Connection, Granite Tops, Washing Machine Connection, Tiled Floors, Tumble Dryer, Built-in Cupboards, Centre Island, Gas Hob', 'Private separate study on ground floor, which can also be used as a bedroom.', 'Tiled Floors', '1', 'Separate domestic room.', '2', 'Open plan with the kitchen, perfect for wine and dine', 'Tiled Floors, Open Plan', 'Tiled Floors, Open Plan', '2', 'Tiled Floors, TV Port, Open Plan', 'Cinema Room on ground floor, with a beautiful starlight effect roof. ', 'Carpets, Projector', '2', 'Temperature controlled Wine Cellar', 'Tiled Floors, Cellar', 'Tiled Floors, Open Plan, Bar Counter', 'With a stunning beautiful designed Koi pond', 'Tiled Floors, Staircase', 'Ground floor Gym, with sliding door that opens completely to the outside of the house.', 'Patio, Tiled Floors, Air Conditioner', '4', 'Electric Door', 'Electric Door', 'Electric Door', 'Electric Door', 'Courtyard', '2', 'Chlorinator, Splash Pool', 'Chlorinator', 'Separate domestic room.', 'Staff Quarters/Domestic Rooms', 'Contemporary, Open Plan, Ultra Modern, Architect-designed', 'North, Green Belt', 'Tile', 'Plaster', 'Aluminium', 'Yes', 'Totally Fenced, Electric Garage, Security Gate, 24 Hour Response, Intercom, Closed Circuit TV, 24 Hour Access, Guard House, Guard, Electric fencing, Perimeter Wall, Outdoor Beams, Boomed Area', 'Air Conditioning Unit, Solar Heating, Fireplace', 'Built in Braai, Sauna, Tennis Court, Balcony, Open Plan, Sliding Doors, Communal braai area, Solar Geyser, Built in Bar', 'Bus, Minibus Taxi', 'ADSL, Fibre', 'Yes', 'No', 'No', 'R 10 500 000', ' 190 Via Firenze Street, Lombardy Estate']}
# ok j
# https://www.property24.com/for-sale/magalieskruin/pretoria/gauteng/4062/110274848
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/magalieskruin/pretoria/gauteng/4062/110274848
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bedroom 4', 'Bedroom 5', 'Bedroom 6', 'Bedroom 7', 'Bedroom 8', 'Bedroom 9', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Bathroom 3', 'Bathroom 4', 'Bathroom 5', 'Bathroom 6', 'Bathroom 7', 'Bathroom 8', 'Bathroom 9', 'Bathroom 10', 'Kitchen', 'Office/study', 'Domestic Rooms', 'Domestic Bathrooms', 'Lounge', 'Dining Room', 'Family/TV Room', 'Entrance Hall', 'Garage', 'Garage 1', 'Garage 2', 'Garage 3', 'Parking', 'Parking 1', 'Parking 2', 'Parking 3', 'Parking 4', 'Parking 5', 'Parking 6', 'Parking 7', 'Parking 8', 'Garden', 'Outbuilding', 'Facing', 'Wall', 'Standalone Building', 'Security', 'Temperature Control', 'Special Features', 'Nearby Public Transport', 'Internet Access', 'price', 'Street Address'], 'values': ['110274848', 'House', 'Multi Storey, Freestanding', '05 August 2021', '1 611 m²', '800 m²', 'R 7 500', 'Yes', '49 %', '9', 'Carpets, Built-in Cupboards', 'Carpets, Built-in Cupboards', 'Carpets, Fireplace, Built-in Cupboards', 'Tiled Floors, Built-in Cupboards', 'Tiled Floors, Built-in Cupboards', 'Carpets, Built-in Cupboards', 'Built-in Cupboards, Laminated Floors', 'Carpets, Built-in Cupboards', 'Carpets, Air Conditioner, Built-in Cupboards, Double Bed', '10', 'Tiled Floors, En suite', 'Tiled Floors, Full', 'Tiled Floors, Bath, Toilet and Basin', 'Tiled Floors, En suite, Shower, Toilet and Basin', 'Tiled Floors, Shower, Toilet and Basin', 'Tiled Floors, Shower, Toilet and Basin', 'Tiled Floors, Bath, Toilet and Basin', 'Tiled Floors, Bath, Toilet and Basin', 'Tiled Floors, Shower, Toilet and Basin', 'Tiled Floors', 'Pantry, Scullery, Dishwasher Connection, Granite Tops, Tiled Floors, Built-in Cupboards, Centre Island, Gas Hob', 'Tiled Floors', '1', '1', 'Tiled Floors, Open Plan', 'Tiled Floors', 'Tiled Floors', 'Tiled Floors', '3', 'Double', 'Double', 'Double', '8', 'Carport', 'Carport', 'Carport', 'Carport', 'Carport', 'Visitors Parking', 'Visitors Parking', 'Visitors Parking', 'Immaculate Condition', 'Staff Quarters/Domestic Rooms, Storeroom, Domestic Bathroom', 'North', 'Face-brick', 'Yes', 'Burglar Bars', 'Air Conditioning Unit', 'Built in Braai, Driveway, Paveway, Open Plan, Water Tanks, Special Doors, Wendy House', 'Bus, Minibus Taxi', 'Dial-up, Fibre', 'R 4 795 000', ' 449 EDELWEISS STREET, Magalieskruin']}
# ok j
# https://www.property24.com/for-sale/wonderboom/pretoria/gauteng/4089/110255886
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/wonderboom/pretoria/gauteng/4089/110255886
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Office/studies', 'Lounges', 'Dining Rooms', 'Garage', 'Parking', 'Gardens', 'Pools', 'Outbuilding', 'Security', 'Temperature Control', 'price', 'Street Address'], 'values': ['110255886', 'House', '02 August 2021', '1 218 m²', 'R 1 480', '5', '4', '1', '1', '1', '1', '3', '3', '1', '1', 'staff room - wendy house', 'alarm , beams . cameras', 'aircons', 'R 4 300 000', ' 135 Tecoma Street, Wonderboom']}
# ok j
# https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110272182
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/lynnwood/pretoria/gauteng/242/110272182
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Kitchens', 'Kitchens', 'Reception Rooms', 'Garage', 'Garden', 'Pool', 'Temperature Control', 'price', 'Street Address'], 'values': ['110272182', 'House', 'Double Storey', '05 August 2021', '746 m²', '335 m²', 'R 1 750', '4', '2.5', 'Main en Suite, Guest Toilet, Bath', '1', 'Scullery, Gas Hob', '1', '2', 'Yes', 'Yes', 'Solar Heating', 'R 3 500 000', '6 Omdraai Street, Lynnwood']}
# ok j
# https://www.property24.com/for-sale/willow-park-manor/pretoria/gauteng/132/110258446
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/willow-park-manor/pretoria/gauteng/132/110258446
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Price per m²', 'Levies', 'Special Levy', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bathroom', 'Kitchen', 'Dining Room', 'Garage', 'Parking', 'Parking 1', 'Parking 2', 'Garden', 'Pools', 'Outbuilding', 'Facing', 'Wall', 'Window', 'Standalone Building', 'Security', 'Special Features', 'Nearby Public Transport', 'Wheelchair Accessible', 'price', 'Street Address'], 'values': ['110258446', 'Apartment / Flat', 'Ground Floor, Simplex', 'Complex, Security Complex, Suburban', '02 August 2021', '14 623 m²', '79 m²', 'R 10 253', 'R 1 400', 'R 0', 'R 300', 'Yes', '2', 'Curtain Rails, Built-in Cupboards, Queen Bed, Laminated Floors', 'Curtain Rails, Built-in Cupboards, Double Bed, Laminated Floors', 'Tiled Floors, Basin, Bath, Shower, Blinds, Toilet', 'Breakfast Nook, Open Plan, Laundry, Stove (Oven & Hob), Fridge, Garbage Disposal, Washing Machine Connection, Tiled Floors, Open Plan, Built-in Cupboards, Under Counter Oven', 'Tiled Floors, Curtain Rails, Open Plan, Veranda', 'Roll up, Covered', '2', 'Secure Parking', 'Visitors Parking', 'Irrigation system, Garden Services, Immaculate Condition', '1', 'Covered Patio', 'North', 'Brick', 'Aluminium', 'No', 'Totally Fenced, Electric Gate, Security Gate, Alarm System, 24 Hour Response, Intercom, Closed Circuit TV, Burglar Bars, 24 Hour Access, Guard House, Guard, Electric fencing, Safe', 'Built in Braai, Sliding Doors, Totally Walled', 'Bus', 'Yes', 'R 810 000', ' 423 Bush Road , Willow Park Manor']}
# ok j
# https://www.property24.com/for-sale/zambezi-manor-lifestyle-estate/pretoria/gauteng/33015/110261302
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/zambezi-manor-lifestyle-estate/pretoria/gauteng/33015/110261302
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Special Levy', 'Rates and Taxes', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bedroom 1', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Bathroom 3', 'Kitchen', 'Lounge', 'Dining Room', 'Braai Room', 'Other', 'Garage', 'Garage 1', 'Garage 2', 'Parking', 'Parking 1', 'Parking 2', 'Garden', 'Size of Outbuildings', 'Style', 'Facing', 'Roof', 'Wall', 'Window', 'Standalone Building', 'Security', 'Special Features', 'Special Features', 'Nearby Public Transport', 'Internet Access', 'Wheelchair Accessible', 'Generator', 'Backup Water', 'price', 'Street Address'], 'values': ['110261302', 'House', 'Double Storey, Freestanding', 'Eco Estate, Estate, Security Estate, Suburban', '03 August 2021', '505 m²', '220 m²', 'R 1 200', 'R 0', 'R 1 400', 'Yes', '43 %', '3', 'MAIN EN-SUITE', 'Tiled Floors, Balcony, Built-in Cupboards, Double Bed', 'Tiled Floors, Balcony, Built-in Cupboards, Double Bed', 'Tiled Floors, Built-in Cupboards, Double Bed', '2.5', 'Tiled Floors, Basin, Guest Toilet', 'Tiled Floors, Full', 'Tiled Floors, Full, En suite', 'Open Plan, Pantry, Scullery, Extractor Fan, Dishwasher Connection, Granite Tops, Tiled Floors, Built-in Cupboards, Under Counter Oven', 'Tiled Floors, TV Port, Open Plan', 'Tiled Floors, Open Plan', 'ENCLOSED PATIO WITH BUILT IN BRAAI', 'COURTYARD', '2', 'Double, Electric Door', 'Double, Electric Door', '2', 'Double', 'Double', 'LARGE, NEAT', '36 m²', 'Modern, Open Plan', 'North', 'Tile', 'Plaster', 'Steel ', 'Yes', '24 Hour Access, Guard', 'ENCLOSED PATIO, AUTOMATED LIGHT SWITCHES, LARGE GARDEN', 'Built in Braai, Paveway, Balcony, Sliding Doors', 'Bus', 'Fibre', 'No', 'No', 'No', 'R 2 710 000', ' 1848 Aventurine Street, ZAMBEZI MANOR LIFESTYLE ESTATE, Zambezi Manor Lifestyle Estate']}
# ok j
# https://www.property24.com/for-sale/garsfontein/pretoria/gauteng/140/110259031
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/garsfontein/pretoria/gauteng/140/110259031
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Listing Date', 'Erf Size', 'Floor Size', 'Special Levy', 'Rates and Taxes', 'Age', 'Pets Allowed', 'Furnished', 'Coverage', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Kitchen', 'Office/study', 'Dining Room', 'Family/TV Room', 'Entrance Hall', 'Parking', 'Garden', 'Size of Outbuildings', 'Roof', 'Wall', 'Standalone Building', 'Security', 'Special Features', 'Nearby Public Transport', 'Internet Access', 'Generator', 'price', 'Street Address'], 'values': ['110259031', 'House', 'Double Storey, Duplex, Duet/Maisonette', '02 August 2021', '500 m²', '193 m²', 'R 0', 'R 1 218', '25', 'Yes', 'Optional', '38 %', '3', 'Fan, Built-in Cupboards, Single Bed, Laminated Floors', 'Fan, Built-in Cupboards, Double Bed, Laminated Floors', 'Built-in Cupboards, King Bed, Laminated Floors', '2', 'Tiled Floors, Shower, Toilet and Basin', 'Tiled Floors, Full, Main en Suite, En suite', 'Breakfast Nook, Pantry, Scullery, Stove (Oven & Hob), Extractor Fan, Dishwasher Connection, Granite Tops, Washing Machine Connection, Tiled Floors, Tumble Dryer, Built-in Cupboards, Centre Island, Country Style, Gas Hob', 'Laminated Floors', 'Internet Port, Laminated Floors', 'Curtain Rails, TV Port, Open Plan, Laminated Floors', 'Laminated Floors', 'Carport, Double', 'Landscaped', '30 m²', 'Tile', 'Brick, Plaster', 'Yes', 'Electric Gate, Alarm System, Intercom, Burglar Bars', 'Built in Braai, Satellite Dish, Special Lights, Sliding Doors, Special Doors, Wendy House', 'Bus, Minibus Taxi', 'Fibre', 'No', 'R 1 649 000', ' 754 Tiervis Street, Garsfontein']}
# ok j
# https://www.property24.com/for-sale/waverley/pretoria/gauteng/3019/110260625
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/waverley/pretoria/gauteng/3019/110260625
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Bathroom 3', 'Kitchen', 'Lounge', 'Dining Room', 'Garage', 'Parking', 'Standalone Building', 'Security', 'Temperature Controls', 'Special Features', 'price', 'Street Address'], 'values': ['110260625', 'House', 'Duet/Maisonette', '03 August 2021', '500 m²', '166 m²', 'R 500', 'R 300', 'Yes', '33 %', '3', 'Tiled Floors, Open Plan, Built-in Cupboards', 'Tiled Floors, Built-in Cupboards', 'Tiled Floors, Built-in Cupboards', '3', 'Tiled Floors, Basin, Toilet', 'Tiled Floors, Basin, Shower, Toilet', 'Tiled Floors, Main en Suite, Bath, Shower, Open Plan, Double Basin, Toilet', 'Open Plan, Extractor Fan, Fridge, Dishwasher Connection, Tiled Floors, Built-in Cupboards, Centre Island, Gas Hob', 'Tiled Floors, Open Plan', 'Tiled Floors, Open Plan', 'Roll up, Single', 'Carport, Single', 'No', 'Electric Garage, Electric Gate', '1', 'Driveway, Sliding Doors, Solar Geyser, Totally Walled', 'R 1 695 000', ' 874 Darling Street, Waverley']}
# ok j
# https://www.property24.com/for-sale/willow-park-manor/pretoria/gauteng/132/110237837
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/willow-park-manor/pretoria/gauteng/132/110237837
# there is a response
# {'page': 0, 'features': [], 'values': []}
# ok j
# https://www.property24.com/for-sale/moreleta-park/pretoria/gauteng/10622/110271203
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/moreleta-park/pretoria/gauteng/10622/110271203
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Lounges', 'Parking', 'price', 'Street Address'], 'values': ['110271203', 'Apartment / Flat', '05 August 2021', '72 m²', 'R 10 556', 'R 1 300', 'R 265', '2', '1', '1', '1', 'Carport', 'R 760 000', ' 85 Kamassie Crescent, Moreleta Park']}
# ok j
# https://www.property24.com/for-sale/garsfontein/pretoria/gauteng/140/110261166
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/garsfontein/pretoria/gauteng/140/110261166
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Coverage', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bedroom 4', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Kitchen', 'Office/study', 'Garage', 'Garage 1', 'Garage 2', 'Parking', 'Garden', 'Internet Access', 'price', 'Street Address'], 'values': ['110261166', 'House', '03 August 2021', '1 190 m²', '298 m²', 'R 870', '25 %', '4', 'King Bed, Laminated Floors', 'Tiled Floors, Built-in Cupboards', 'Tiled Floors, Built-in Cupboards', 'Tiled Floors, Built-in Cupboards, King Bed', '2', 'Full, Main en Suite', 'Bath, Toilet and Basin', 'Breakfast Nook, Stove (Oven & Hob), Granite Tops, Built-in Cupboards', 'Laminated Floors', '2', 'Electric Door', 'Single', 'Visitors Parking, Carport', 'Borehole, Irrigation system', 'Fibre', 'R 2 150 000', ' 497 De Bron Road, Garsfontein']}
# ok j
# ...
# ok j
# https://www.property24.com/for-sale/sinoville/pretoria/gauteng/4080/110274372
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/sinoville/pretoria/gauteng/4080/110274372
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Dining Rooms', 'Family/TV Rooms', 'Garage', 'Parking', 'Gardens', 'price', 'Street Address'], 'values': ['110274372', 'Apartment / Flat', '05 August 2021', '148 m²', 'R 10 777', 'R 1 585', 'R 789', 'Yes', '3', '2', '1', '1', '1', '2', '2', '1', 'R 1 595 000', ' 182 Pafuri Mews,\n209 Ongers Street, Sinoville']}
# ok j
# https://www.property24.com/for-sale/the-meadows/pretoria/gauteng/15187/110274602
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/the-meadows/pretoria/gauteng/15187/110274602
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Office', 'Lounges', 'Dining Rooms', 'Garage', 'Pool', 'price'], 'values': ['110274602', 'House', '05 August 2021', '713 m²', '275 m²', 'R 1 300', 'R 2 300', 'Yes', '3', '2.5', '1', '1', '1', '1', '2', 'Yes', 'R 3 350 000']}
# ok j
# https://www.property24.com/for-sale/waterkloof-heights/pretoria/gauteng/3973/110116627
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/waterkloof-heights/pretoria/gauteng/3973/110116627
# there is a response
# {'page': 0, 'features': [], 'values': []}
# ok j
# https://www.property24.com/for-sale/the-meadows/pretoria/gauteng/15187/110166555
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/the-meadows/pretoria/gauteng/15187/110166555
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Lounges', 'Dining Rooms', 'Garage', 'price'], 'values': ['110166555', 'House', '06 July 2021', '590 m²', '245 m²', 'R 1 380', 'R 1 920', 'Yes', '3', '2.5', '1', '1', '1', '2', 'R 3 070 000']}
# ok j
# https://www.property24.com/for-sale/faerie-glen/pretoria/gauteng/165/110275189
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/faerie-glen/pretoria/gauteng/165/110275189
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Office/studies', 'Lounges', 'Dining Rooms', 'Family/TV Rooms', 'Parking', 'Parking 1', 'Parking 2', 'Parking 3', 'Gardens', 'Pools', 'Standalone Building', 'price', 'Street Address'], 'values': ['110275189', 'House', '06 August 2021', '1 621 m²', '390 m²', 'R 1 580', 'Yes', '24 %', '5', '3', '2', '1', '1', '1', '1', '3', 'Carport', 'Carport', 'Carport', '1', '1', 'Yes', 'R 2 500 000', ' 366 Vista Drive, Faerie Glen']}
# ok j
# https://www.property24.com/for-sale/pretoria-central/pretoria/gauteng/27/110278282
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/pretoria-central/pretoria/gauteng/27/110278282
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedroom', 'Bathrooms', 'Dining Rooms', 'Parking', 'price', 'Street Address'], 'values': ['110278282', 'Apartment / Flat', '06 August 2021', '76 m²', 'R 4 539', 'R 1 603', 'R 98', 'No', '1.5', '1.5', '1', '1', 'R 345 000', '569 Van Der Walt Street, Pretoria Central']}
# ok j
# https://www.property24.com/for-sale/pretoria-west/pretoria/gauteng/2924/108419173
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/pretoria-west/pretoria/gauteng/2924/108419173
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Dining Rooms', 'Parking', 'price', 'Street Address'], 'values': ['108419173', 'Apartment / Flat', '04 August 2021', '77 m²', 'R 5 000', 'R 1 168', 'R 133', 'No', '2', '1', '1', '1', 'R 385 000', '31109 FREDERICK STREET, Pretoria West']}
# ok j
# https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110277952
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110277952
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Price per m²', 'Levies', 'Bedrooms', 'Bathrooms', 'Parking', 'Special Feature', 'price', 'Street Address'], 'values': ['110277952', 'Apartment / Flat', '06 August 2021', '2 441 m²', '83 m²', 'R 6 024', 'R 2 000', '3', '1', '1 Carport', 'Lifts', 'R 500 000', ' Arcadia, 743 / Hilrianda, Arcadia']}
# ok j
# https://www.property24.com/for-sale/muckleneuk/pretoria/gauteng/32/110273895
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/muckleneuk/pretoria/gauteng/32/110273895
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedroom', 'Bathrooms', 'Lounges', 'Parking', 'price', 'Street Address'], 'values': ['110273895', 'Apartment / Flat', '05 August 2021', '89 m²', 'R 5 449', 'R 1 606', 'R 256', 'No', '2.5', '1', '1', '1', 'R 485 000', '419 WALKER STREET, Muckleneuk']}
# ok j
# https://www.property24.com/for-sale/olympus-ah/pretoria/gauteng/12201/110269797
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/olympus-ah/pretoria/gauteng/12201/110269797
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Kitchen', 'Lounge', 'Dining Room', 'Braai Room', 'Entrance Hall', 'Rooms', 'Garage', 'Garage 1', 'Garage 2', 'Parking', 'Garden', 'Security', 'Special Feature', 'price', 'Street Address'], 'values': ['110269797', 'House', 'Single Storey', 'Estate, Security Estate', '04 August 2021', '449 m²', '164 m²', 'R 1 090', 'R 2 500', 'Yes', '3', ' ', ' ', ' ', '2', ' ', ' ', ' ', ' ', ' ', 'Patio', '2', ' ', ' ', '2', 'Yes', 'Electric fencing', 'Built in Braai', 'R 2 450 000', ' 2401 Ajax Avenue, Olympus AH']}
# ok j
# https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110269850
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110269850
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedroom', 'Bathrooms', 'Kitchen', 'Dining Room', 'Parking', 'Security', 'price', 'Street Address'], 'values': ['110269850', 'Apartment / Flat', 'Complex, Security Complex', '04 August 2021', '1 110 m²', '59 m²', 'R 5 932', 'R 1 190', 'R 128', 'No', ' ', '1', ' ', ' ', '1', 'Security Gate', 'R 350 000', ' 302 Keshogat, 516 Edmond, Arcadia']}
# ok j
# https://www.property24.com/for-sale/equestria/pretoria/gauteng/266/110277685
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/equestria/pretoria/gauteng/266/110277685
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Floor Size', 'Price per m²', 'Levies', 'Rates and Taxes', 'Bedroom', 'Bathrooms', 'Bathrooms', 'Kitchen', 'Rooms', 'Parking', 'Parking', 'Facing', 'Roof', 'Floor', 'price', 'Street Address'], 'values': ['110277685', 'Apartment / Flat', '06 August 2021', '77 m²', 'R 8 442', 'R 1 800', 'R 435', '1', '1', 'Shower', 'Open Plan, Laundry, Extractor Fan, Under Counter Oven', 'Veranda', 'Parking features', 'Carport', 'North', 'Tile', 'Carpets, Tiled Floors', 'R 650 000', '79 Oukraal Boulevard, Equestria']}
# ok j
# https://www.property24.com/for-sale/montana/pretoria/gauteng/3984/110166638
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/montana/pretoria/gauteng/3984/110166638
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Bathrooms', 'Kitchens', 'Dining Room', 'Family/TV Room', 'Garage', 'Garden', 'Security', 'Special Feature', 'price'], 'values': ['110166638', 'House', '06 July 2021', '500 m²', '250 m²', 'R 1 320', 'R 700', 'Yes', '3', '2', 'Main en Suite', '1', '1', '1', '2', 'Yes', 'Security Gate', 'Built in Braai, Balcony', 'R 2 300 000']}
# ok j
# https://www.property24.com/for-sale/montana-park/pretoria/gauteng/4070/110273172
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/montana-park/pretoria/gauteng/4070/110273172
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bathrooms', 'Kitchen', 'Lounge', 'Dining Room', 'Braai Room', 'Rooms', 'Garage', 'Garden', 'Security', 'Special Feature', 'price', 'Street Address'], 'values': ['110273172', 'House', '05 August 2021', '500 m²', '160 m²', 'R 1 500', 'R 800', 'Yes', '3', '2', 'Scullery', 'Lounge', 'DiningRoom', 'BraaiRoom', 'Patio', '2', 'Garden', 'Security Gate, Burglar Bars, Guard House', 'Built in Braai', 'R 1 499 000', '500 Veda Avenue, Montana Park']}
# ok j
# https://www.property24.com/for-sale/mayville/pretoria/gauteng/319/110277210
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mayville/pretoria/gauteng/319/110277210
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Age', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Lounges', 'Dining Rooms', 'Garage', 'Gardens', 'Pools', 'Outbuilding', 'Size of Outbuildings', 'Style', 'Facing', 'Roof', 'Wall', 'Window', 'Standalone Building', 'Special Features', 'Nearby Public Transport', 'Internet Access', 'price', 'Street Address'], 'values': ['110277210', 'House', 'Freestanding', 'Suburban', '06 August 2021', '534 m²', '150 m²', 'R 750', '46', 'Yes', '28 %', '3', '1', '1', '1', '1', '2', '1', '1', 'Flat without bathroom- room', '50 m²', 'Conventional', 'Street Front', 'Zinc', 'Plaster', 'Steel ', 'Yes', 'Built in Braai, Totally Walled', 'Bus, Minibus Taxi', 'Fibre', 'R 1 360 000', ' 815 Mance Avenue, Mayville']}
# ok j
# https://www.property24.com/for-sale/boardwalk-meander/pretoria/gauteng/10861/108433901
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/boardwalk-meander/pretoria/gauteng/10861/108433901
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Floor Size', 'Levies', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bedroom 4', 'Bathrooms', 'Kitchen', 'Office/study', 'Domestic Rooms', 'Lounges', 'Lounge 1', 'Lounge 2', 'Dining Room', 'Braai Room', 'Entrance Hall', 'Rooms', 'Garage', 'Garage 1', 'Garage 2', 'Garage 3', 'Garden', 'Pool', 'Special Feature', 'Internet Access', 'price', 'Street Address'], 'values': ['108433901', 'House', 'Double Storey', 'Estate, Fishing Estate, Security Estate', '05 August 2021', '804 m²', '487 m²', 'R 1 710', 'R 2 900', 'Yes', '4', ' ', ' ', ' ', ' ', '3.5', ' ', ' ', '1', '2', ' ', ' ', ' ', ' ', ' ', 'Patio', '3', ' ', ' ', ' ', 'Yes', 'Yes', 'Built in Braai, Tennis Court', 'Satellite', 'R 4 990 000', ' Boardwalk Meander Estate, 6 Featherbed Street, Boardwalk Meander']}
# ok j
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/pretoria/gauteng/1/p5?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# ['https://www.property24.com/for-sale/villieria/pretoria/gauteng/3018/110226051', 'https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110269882', 'https://www.property24.com/for-sale/meadows-security-estate/pretoria/gauteng/17913/110278547', 'https://www.property24.com/for-sale/equestria/pretoria/gauteng/266/110266655', 'https://www.property24.com/for-sale/menlo-park/pretoria/gauteng/259/110240780', 'https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110116746', 'https://www.property24.com/for-sale/wonderboom/pretoria/gauteng/4089/110272605', 'https://www.property24.com/for-sale/wonderboom-south/pretoria/gauteng/327/110271727', 'https://www.property24.com/for-sale/magalieskruin/pretoria/gauteng/4062/110268840', 'https://www.property24.com/for-sale/villieria/pretoria/gauteng/3018/110224380', 'https://www.property24.com/for-sale/willow-park-manor/pretoria/gauteng/132/110266240', 'https://www.property24.com/for-sale/annlin/pretoria/gauteng/4022/110274267', 'https://www.property24.com/for-sale/sunnyside/pretoria/gauteng/41/110273421', 'https://www.property24.com/for-sale/boardwalk-meander/pretoria/gauteng/10861/110261557', 'https://www.property24.com/for-sale/hatfield/pretoria/gauteng/304/107917748', 'https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110222117', 'https://www.property24.com/for-sale/waverley/pretoria/gauteng/3019/110258569', 'https://www.property24.com/for-sale/wonderboom/pretoria/gauteng/4089/110273764', 'https://www.property24.com/for-sale/rietvalleirand/pretoria/gauteng/603/110274772', 'https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110258537', 'https://www.property24.com/for-sale/erasmuskloof/pretoria/gauteng/2916/107560926']
# https://www.property24.com/for-sale/villieria/pretoria/gauteng/3018/110226051
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/villieria/pretoria/gauteng/3018/110226051
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathroom', 'Kitchen', 'Office/study', 'Lounge', 'Dining Room', 'Garage', 'Parking', 'Parking 1', 'Parking 2', 'Parking 3', 'Outbuilding', 'Standalone Building', 'Wheelchair Accessible', 'price', 'Street Address'], 'values': ['110226051', 'House', 'Freestanding', '23 July 2021', '1 000 m²', '220 m²', 'R 1 000', 'Yes', '22 %', '3', 'Parquet Floors, Curtain Rails, Built-in Cupboards', 'Parquet Floors, Curtain Rails, Built-in Cupboards', 'Parquet Floors, Curtain Rails, Built-in Cupboards', 'Tiled Floors, Separate Toilet, Basin, Bath, Shower', 'Stove (Oven & Hob), Tiled Floors, Built-in Cupboards', 'Parquet Floors, Curtain Rails', 'Curtain Rails', 'Curtain Rails', 'Single', '3', 'Double', 'Double', 'Single', 'Workshop', 'Yes', 'Yes', 'R 1 590 000', ' 934 33Rd Avenue, Villieria']}
# ok j
# https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110269882
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/arcadia/pretoria/gauteng/301/110269882

# %%
sh = ScrapingHouse("https://www.property24.com/for-sale/blue-hills-country-estate/midrand/gauteng/12992/110279545")
sh.getData()
# Out:
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/blue-hills-country-estate/midrand/gauteng/12992/110279545
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Levies', 'No Transfer Duty', 'Rates and Taxes', 'price', 'Street Address'], 'values': ['110279545', 'Vacant Land / Plot', '07 August 2021', '5 049 m²', 'R 4 300', 'Yes', 'R 8 300', 'R 3 800 000', ' 1776 Blue Hills Equestrian Estate, Midrand, Blue Hills Country Estate']}
# {'page': 0,
#  'features': ['Listing Number',
#   'Type of Property',
#   'Listing Date',
#   'Erf Size',
#   'Levies',
#   'No Transfer Duty',
#   'Rates and Taxes',
#   'price',
#   'Street Address'],
#  'values': ['110279545',
#   'Vacant Land / Plot',
#   '07 August 2021',
#   '5 049 m²',
#   'R 4 300',
#   'Yes',
#   'R 8 300',
#   'R 3 800 000',
#   ' 1776 Blue Hills Equestrian Estate, Midrand, Blue Hills Country Estate']}
