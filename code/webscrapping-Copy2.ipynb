# %%
import requests
import numpy as np
import csv
from bs4 import BeautifulSoup

# %%
class ScraperApi:
    
    def __init__(self,url):
        _key = "1a18230ed0f817673163d7cc6d39e7bc"
        self.key = _key
        self.url_scraper ="http://api.scraperapi.com?api_key=" + self.key + "&url=" + url
        print(self.url_scraper)
        
    def getSoup(self):
        response = requests.get(self.url_scraper)
        
        if response.status_code != 200:
            print('Error with your request: ' + str(response.status_code))
        
        else:
            print('there is a response')
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup

# %%
class ScrapingBee:
    def __init__(self, url_site):
        
        # mamorina compte scrapingBee @gmail dia alaina iny key iny dia apetaka eto dia mandeha
        
        key = "9G9UA49KMOZT46FW014R726HPDYT3BSQU7HXRWGB3ZFNH4OZDUIMEQPMKWLMSOL4J8Z6I836OXCFXD0E"
        self.SCRAPINGBEE_API_KEY = key
        self.endpoint = "https://app.scrapingbee.com/api/v1"
        self.params = {
            'api_key': self.SCRAPINGBEE_API_KEY,
            'url': url_site,
            'render_js': 'false', 
        }
        
        self.url_site = url_site
        
        self.page = requests.get(self.url_site)
        
    def getSoup(self):
        response = requests.get(self.endpoint, params=self.params)
        
        if response.status_code != 200:
            print('Error with your request: ' + str(response.status_code))
        
        else:
            print('there is a response')
            soup = BeautifulSoup(response.content, 'html.parser')
            return soup
        
    def getSoupTraditionnal(self):
        soup = BeautifulSoup(self.page.content,'html.parser')
        return soup
        
        
class FileCsv:
    
    def __init__(self, _path):
        self.path = _path
        
    def setHeader(self,header):
        with open(self.path, 'w') as f:
            writer = csv.writer(f)
            writer.writerow(header)
        
    def addColumn(self, row):
        with open(self.path, 'a') as f:
            writer = csv.writer(f)
            writer.writerow(row)
            
    def read(self, _path):
        with open(_path,'r') as f:
            spamreader = csv.reader(f, delimiter=',')
            for row in spamreader:
                print(row)

# %%
# scraping a page with all details
    
class ScrapingHouse:
    
    def __init__(self,url_house):
        self.url = url_house
        
        sb = ScraperApi(url_house)
        self.soup = sb.getSoup()

        self.features = {
            'page' : 0,
            'features' : [],
            'values' : []
        }
        self.path = ""
        
        self.liensVille = []
        
    def getData(self):
        
        if self.soup:
            
            features = self.soup.find_all('div',class_='p24_propertyOverviewKey')
            datas = self.soup.find_all('div',class_='p24_info')
            div_price = self.soup.find_all('div',class_="p24_mBM")
            
            if features and datas and div_price:
                
                price = div_price[0].find_all('div','p24_price')[0].text 
                
                for i in range(np.shape(datas)[0]):
                    self.features['values'].append(datas[i].text)
                    features = datas[i].parent.parent.div.text
                    self.features['features'].append(features)

                self.features['features'].append('price')
                self.features['values'].append(price)


                # adding the adress if exist

                a = self.soup.find('a',class_="p24_addressPropOverview")

                if a:
                    adress = a.text
                    features_adress = a.parent.parent.div.text
                    self.features['features'].append(features_adress)
                    self.features['values'].append(adress)

        print(self.features)
        
        
            
#         for i in range(np.shape(features)[0]):
# #             self.features['features'].append(features[i].text)
#             print(features[i].text)
    
#         print('--------------')
        
#         for i in range(np.shape(datas)[0]):
#             print(datas[i].text)
            
#         print(self.features)
        
#         for i in range(np.shape(datas)[0]):
#             self.features['values'].append(datas[i].text)
            
        return self.features
    
    def saveData(self,page):
        
        file = FileCsv('../data/house_price/' + page + '.csv')
        file.setHeader(self.features['features'])
        file.addColumn(self.features['values'])

# %%
class ScrapingProvince:
    
    def __init__(self,url_prov):
        self.url_page = []
        self.nb_page = 0
        self.page = requests.get(url_prov)
        self.url_prov = url_prov
    
    def findUrlPage(self):
        sb = ScraperApi(self.url_prov)
        soup = sb.getSoup()
#         print(soup)
        
        ul_pagination = soup.find_all("ul",class_="pagination")
        li = ul_pagination[0].find_all("li")

        last_page = int(li[np.shape(li)[0]-1].a.get('data-pagenumber'))
        
        for i in range(last_page):
            split = self.url_prov.split('?')

            split[0] += '/p' + str(i+1) + '?'
            url = split[0] + split[1]
            self.url_page.append(url)
            
        print(self.url_page)
            
        return self.url_page
        
    def saveUrl(self,province):
        file = FileCsv('../data/province/page/' + province + '.csv')
        file.setHeader(self.features['features'])
        file.addColumn(self.features['values'])

# %%
class ScrapingPage:
    
    def __init__(self,url_page):
        self.url_page = url_page
        self.soup = ScraperApi(url_page).getSoup()
        self.url_house = []
        
    def getAllUrlHouse(self):
        soup = self.soup
        div_container = soup.find_all('div','p24_regularTile')
        list_href = []
        
        for i in range(np.shape(div_container)[0]):
             list_href.append('https://www.property24.com' + div_container[i].a.get('href'))
        
        self.url_house = list_href
        
        print(self.url_house)
        
        return self.url_house

# %%
class Site:
    def __init__(self, url):
        self.url = url
        self.url_ville = []
        self.url_page_ville = []  # ato misy lien ana page bdb
        self.list_url_house = []
        self.url_page = []
        
    def findUrlVille(self):
#         soup = ScrapingBee(self.url).getSoupTraditionnal()
        
        soup = ScraperApi(self.url).getSoup() 
        
        div = soup.find_all('div',class_='p24_popular')
        
        file = FileCsv('../data/ville/url_ville.csv')
        file.setHeader(['url_ville'])
        
        for i in range(np.shape(div)[0]):
            a = div[i].find_all('a')
            for j in range(np.shape(a)[0]):
                if j== np.shape(a)[0]-3:
                    break
                else:
                    url = 'https://www.property24.com'+ a[j].get('href') + '?PropertyCategory=House%2cApartmentOrFlat'
                    self.url_ville.append(url)
                    file.addColumn([url])
        
    # prend en parametre un tableau d'url_ville et le parcours pour obtenir les liens_de son page
    # liens des (1......5689)
    
    def findUrlPageVille(self, url_ville):
        
        url_page = []
        
        for i in range(np.shape(url_ville)[0]):
            
            sp = ScrapingProvince(url_ville[i])
            url_page_one = sp.findUrlPage()
            url_page.append(url_page_one)
            self.url_page = url_page[0]
        
    def getContentPageVille(self,name_file):  # maka ny lien an'ilay house ao anaty ilay page
        
        file = FileCsv('../data/house_price/house_' + name_file + '.csv')
        file.setHeader(['data_house'])
        
        for i in range(np.shape(self.url_page)[0]):
            sp = ScrapingPage(self.url_page[i])
            
            allUrlHouse = sp.getAllUrlHouse()
            
            for j in range(np.shape(allUrlHouse)[0]):
                self.getDataHouse(allUrlHouse[j],file)
                print('ok j')
    
    def getDataHouse(self,url_house,file):
        
        print(url_house)
        
        sh = ScrapingHouse(url_house)
        features = sh.getData()
        
        file.addColumn(features['features'])
        file.addColumn(features['values'])

# %%
site= Site('https://www.property24.com')
print ('ok')
# --- atao valeur an'io tableau io ilay lien ana province tiana ho alaina dia mahazo ny house rehetra ao aminy--
# --- 

lien_province_tiana_alaina = 'https://www.property24.com/for-sale/mabopane/gauteng/76?PropertyCategory=House%2cApartmentOrFlat'
url_ville = [lien_province_tiana_alaina]

site.findUrlPageVille(url_ville)

# ovana ilay name_file dia ville no aloha dia province no farany, raha /mabopane/gauteng izany ilay lien ohatra dia lasa
# mabopane_gauteng ilay fichier istoquer-na anazy

name_file = "mabopane_gauteng"
site.getContentPageVille(name_file)
# Out:
# ok
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/gauteng/76?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# ['https://www.property24.com/for-sale/mabopane/gauteng/76/p1?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p2?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p3?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p4?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p5?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p6?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p7?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p8?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p9?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p10?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p11?PropertyCategory=House%2cApartmentOrFlat', 'https://www.property24.com/for-sale/mabopane/gauteng/76/p12?PropertyCategory=House%2cApartmentOrFlat']
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/gauteng/76/p1?PropertyCategory=House%2cApartmentOrFlat
# there is a response
# ['https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110268829', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235425', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235396', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110244159', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110220365', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110226424', 'https://www.property24.com/for-sale/odinburg-gardens/mabopane/gauteng/3026/110209705', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110208225', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235470', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110190074', 'https://www.property24.com/for-sale/winterveldt/mabopane/gauteng/3029/110232932', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110178823', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110147605', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235381', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110264036', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235409', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110169068', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110149035', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110271443', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110144752', 'https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110252553']
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110268829
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110268829
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bathroom', 'Kitchen', 'Lounge', 'Style', 'Facing', 'Roof', 'Wall', 'Window', 'Standalone Building', 'Security', 'Nearby Public Transport', 'Wheelchair Accessible', 'Generator', 'Backup Water', 'price', 'Street Address'], 'values': ['110268829', 'House', 'New Development, Bungalow', 'Metropolitan', '04 August 2021', '500 m²', 'R 234', 'Yes', '2', 'Tiled Floors, Curtain Rails, Queen Bed', 'Tiled Floors, Curtain Rails, Queen Bed', 'Tiled Floors, Bath, Curtain Rails, Toilet', 'Stove, Tiled Floors, Curtain Rails', 'Tiled Floors, Curtain Rails', 'Traditional', 'Above Road', 'Asbestos', 'Plaster', 'Steel ', 'Yes', 'Totally Fenced, Security Gate, Burglar Bars, Safe', 'Bus, Minibus Taxi', 'No', 'No', 'No', 'R 395 000', ' MABOPANE, Mabopane']}
# ok j
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235425
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235425
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Pets Allowed', 'Furnished', 'Coverage', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Parking', 'Gardens', 'Standalone Building', 'Security', 'Nearby Public Transport', 'Internet Access', 'Wheelchair Accessible', 'Backup Water', 'price', 'Street Address'], 'values': ['110235425', 'House', '26 July 2021', '290 m²', '70 m²', 'R 200', 'Yes', 'Yes', '24 %', '3', '1', '1', '1', '1', 'Yes', '1', 'Bus, Train, Minibus Taxi', 'Fibre', 'Yes', 'Yes', 'R 490 000', ' Mabopane Sunvelly, Mabopane']}
# ok j
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235396
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235396
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Rates and Taxes', 'Pets Allowed', 'Coverage', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Parking', 'Gardens', 'Roof', 'Standalone Building', 'Security', 'price', 'Street Address'], 'values': ['110235396', 'House', '26 July 2021', '290 m²', '70 m²', 'R 200', 'Yes', '24 %', '3', '1', '1', '1', '1', 'Tile', 'Yes', 'Burglar Bars', 'R 490 000', ' Mabopane sunvelly, Mabopane']}
# ok j
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110244159
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110244159
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Floor Size', 'Pets Allowed', 'Furnished', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Dining Rooms', 'Parking', 'Garden', 'price', 'Street Address'], 'values': ['110244159', 'House', '28 July 2021', '300 m²', '60 m²', 'No', 'Yes', '2', '1', '1', '1', '1', 'Yes', 'R 550 000', '12 nkuna street, Mabopane']}
# ok j
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110220365
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110220365
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Kitchen', 'Office/study', 'Lounge', 'Garage', 'Style', 'Facing', 'Roof', 'Standalone Building', 'Security', 'Nearby Public Transport', 'Wheelchair Accessible', 'Generator', 'Backup Water', 'price', 'Street Address'], 'values': ['110220365', 'House', 'New Development, Bungalow, Freestanding', 'Metropolitan', '21 July 2021', '350 m²', 'R 300', 'Yes', '3', 'Tiled Floors, Curtain Rails, Double Bed', 'Tiled Floors, Curtain Rails, King Bed', 'Tiled Floors, Curtain Rails, Double Bed', '2', 'Tiled Floors, Basin, Shower, Curtain Rails, Toilet', 'Tiled Floors, Basin, Curtain Rails, Toilet', 'Stove, Tiled Floors, Curtain Rails, Built-in Cupboards, Under Counter Oven, Hob', 'Tiled Floors, Curtain Rails', 'Tiled Floors, Curtain Rails', 'Roll up, Single, Covered', 'Modern, Traditional', 'North, Street Front', 'Tile', 'Yes', 'Totally Fenced, Security Gate, Burglar Bars, Perimeter Wall, Safe', 'Bus, Minibus Taxi', 'No', 'No', 'No', 'R 699 900', ' Lebanon, Mabopane, Mabopane']}
# ok j
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110226424
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110226424
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Kitchen', 'Lounge', 'Dining Room', 'Garage', 'Parking', 'Garden', 'price', 'Street Address'], 'values': ['110226424', 'House', 'New Development', '23 July 2021', '258 m²', 'R 439', 'No', '3', ' ', ' ', ' ', '1', ' ', ' ', ' ', ' ', '1', 'Yes', 'R 699 000', ' 12311 Mabopane unit X, Mabopane']}
# ok j
# https://www.property24.com/for-sale/odinburg-gardens/mabopane/gauteng/3026/110209705
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/odinburg-gardens/mabopane/gauteng/3026/110209705
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathrooms', 'Bathroom 1', 'Bathroom 2', 'Bathroom 3', 'Kitchen', 'Lounge', 'Family/TV Room', 'Garage', 'Garage 1', 'Garage 2', 'Style', 'Facing', 'Roof', 'Wall', 'Window', 'Standalone Building', 'Security', 'price', 'Street Address'], 'values': ['110209705', 'House', 'New Development, Bungalow', 'Metropolitan', '19 July 2021', '500 m²', 'R 236', 'Yes', '3', 'Tiled Floors, Curtain Rails, Queen Bed', 'Tiled Floors, Curtain Rails, Queen Bed', 'Tiled Floors, Curtain Rails, Built-in Cupboards, Queen Bed', '3', 'Tiled Floors, Basin, Guest Toilet, Bath, Curtain Rails', 'Tiled Floors, Basin, Main en Suite, Bath, Curtain Rails, Toilet', 'Tiled Floors, Separate Toilet, Guest Toilet, Curtain Rails, Toilet', 'Fridge, Tiled Floors, Curtain Rails, Built-in Cupboards', 'Tiled Floors, Curtain Rails, Open Plan', 'Tiled Floors, Curtain Rails, Open Plan', '2', 'Double, Covered', 'Double, Covered', 'Open Plan, Traditional', 'Above Road', 'Tile', 'Plaster', 'Steel ', 'Yes', 'Totally Fenced, Security Gate, Burglar Bars, Safe', 'R 579 900', ' ODINBURG GARDENS, Odinburg Gardens']}
# ok j
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110208225
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110208225
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Description', 'Lifestyle', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Pets Allowed', 'Bedrooms', 'Bedroom 1', 'Bedroom 2', 'Bedroom 3', 'Bathroom', 'Kitchen', 'Lounge', 'Parking', 'Style', 'Facing', 'Roof', 'Wall', 'Window', 'Standalone Building', 'Security', 'Nearby Public Transport', 'Wheelchair Accessible', 'Generator', 'Backup Water', 'price', 'Street Address'], 'values': ['110208225', 'House', 'New Development, Bungalow', 'Metropolitan', '19 July 2021', '300 m²', 'R 236', 'Yes', '3', 'Tiled Floors, Curtain Rails, Built-in Cupboards, Queen Bed', 'Tiled Floors, Curtain Rails, Built-in Cupboards, Queen Bed', 'Tiled Floors, Curtain Rails, Built-in Cupboards, Queen Bed', 'Tiled Floors, Basin, Bath, Curtain Rails, Toilet', 'Stove, Tiled Floors, Curtain Rails, Built-in Cupboards', 'Tiled Floors, Curtain Rails, Open Plan', 'Carport, Shade net covered', 'Open Plan, Traditional', 'Above Road', 'Tile', 'Plaster', 'Steel ', 'Yes', 'Totally Fenced, Security Gate, Closed Circuit TV, Burglar Bars, Safe', 'Bus, Minibus Taxi', 'No', 'No', 'No', 'R 560 000', ' ODINBURG GARDENS , Mabopane']}
# ok j
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235470
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110235470
# there is a response
# {'page': 0, 'features': ['Listing Number', 'Type of Property', 'Listing Date', 'Erf Size', 'Rates and Taxes', 'Bedrooms', 'Bathrooms', 'Kitchens', 'Parking', 'Gardens', 'Security', 'Nearby Public Transport', 'Internet Access', 'Wheelchair Accessible', 'Backup Water', 'price', 'Street Address'], 'values': ['110235470', 'House', '26 July 2021', '290 m²', 'R 200', '3', '1', '1', '1', '1', 'Burglar Bars', 'Bus, Train, Minibus Taxi', 'Fibre', 'Yes', 'Yes', 'R 490 000', ' Mabopane Sunvelly, Mabopane']}
# ok j
# https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110190074
# http://api.scraperapi.com?api_key=1a18230ed0f817673163d7cc6d39e7bc&url=https://www.property24.com/for-sale/mabopane/mabopane/gauteng/3025/110190074
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     275             # sending a valid response.
# --> 276             raise RemoteDisconnected("Remote end closed connection without"
#     277                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-9-43822c8ec344> in <module>
#      13
#      14 name_file = "mabopane_gauteng"
# ---> 15 site.getContentPageVille(name_file)
#
# <ipython-input-7-e5c754148019> in getContentPageVille(self, name_file)
#      52
#      53             for j in range(np.shape(allUrlHouse)[0]):
# ---> 54                 self.getDataHouse(allUrlHouse[j],file)
#      55                 print('ok j')
#      56
#
# <ipython-input-7-e5c754148019> in getDataHouse(self, url_house, file)
#      59         print(url_house)
#      60
# ---> 61         sh = ScrapingHouse(url_house)
#      62         features = sh.getData()
#      63
#
# <ipython-input-4-715626d78210> in __init__(self, url_house)
#       7
#       8         sb = ScraperApi(url_house)
# ----> 9         self.soup = sb.getSoup()
#      10
#      11         self.features = {
#
# <ipython-input-2-07e3414ec3a6> in getSoup(self)
#       8
#       9     def getSoup(self):
# ---> 10         response = requests.get(self.url_scraper)
#      11
#      12         if response.status_code != 200:
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
sh = ScrapingHouse("https://www.property24.com/for-sale/blue-hills-country-estate/midrand/gauteng/12992/110279545")
sh.getData()
